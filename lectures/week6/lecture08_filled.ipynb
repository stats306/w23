# %%
library(tidyverse)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# earnings differences, men vs women
load(url('https://datasets.stats306.org/cps.RData'))



earnings %>% select(education, year, sex, Mean) %>% pivot_wider(names_from = sex, values_from = Mean) %>% 
    mutate(ratio = male / female) %>% 
        ggplot(aes(x = year, y = ratio)) + geom_line(aes(color = education)) + 
    geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
# make better plot

# %% [markdown]
# To explore this relationship further, we naturally want to bring in other data. For example, one hypothesis is that the wage gap is diminshing in part because women are having fewer children. To study this, we want to get some data about childbearing tendencies in the U.S., and see study how it relates to the wage gap.

# %% [markdown]
# The U.S. census has [detailed data](https://www.census.gov/data/tables/time-series/demo/fertility/his-cps.html#par_list) on female childbearing over time.

# %% [markdown]
# I have gone ahead and extracted these a subset of this spreadsheet into the following data frame:

# %%
pct_childless <- tibble::tribble(
  ~year, ~X25.29, ~X35.39,
   2018,    54.2,    33.6,
   2016,    53.8,    30.8,
   2014,    49.6,    28.9,
   2012,    49.4,    28.2,
   2010,    47.6,    29.7,
   2008,    46.2,    26.8,
   2006,    45.6,    26.2,
   2004,    44.2,    27.6,
   2002,    45.5,    27.7,
   2000,    44.2,    28.1,
   1998,    43.5,    27.4,
   1995,    43.8,    26.7,
   1994,    43.6,    26.3,
   1992,    41.3,    26.1,
   1990,    42.1,    25.7,
   1988,    42.2,    25.1,
   1987,    39.3,    23.6,
   1986,    40.7,    23.9,
   1985,    41.5,    26.2,
   1984,    39.9,    23.5,
   1983,    39.5,    22.9,
   1982,    38.8,    22.5,
   1981,    37.2,    20.6,
   1980,    36.8,    19.8,
   1976,    30.8,    15.6
  )

# %% [markdown]
# (Next week you will learn how to import data from spreadsheets on your own.)

# %%
print(pct_childless)
# Out:
# # A tibble: 25 × 3
#     year X25.29 X35.39
#    <dbl>  <dbl>  <dbl>
#  1  2018   54.2   33.6
#  2  2016   53.8   30.8
#  3  2014   49.6   28.9
#  4  2012   49.4   28.2
#  5  2010   47.6   29.7
#  6  2008   46.2   26.8
#  7  2006   45.6   26.2
#  8  2004   44.2   27.6
#  9  2002   45.5   27.7
# 10  2000   44.2   28.1
# # … with 15 more rows

# %% [markdown]
# To compare these data, we need to somehow "match up" the data in `earnings` and `pct_childless`. An "ideal" table for studying this relationship would look like:
#
# ```
#     # A tibble: 25 × 3
#         year   age     wage.gap   pct.childless
#        <dbl>  <fct>   <dbl>      <dbl>
#      1  2018   25-29   1.451      .14
#      2  2018   35-39   1.143      .10
#     # … with 23 more rows
# ```

# %% [markdown]
# This lecture will teach us about "joining" data in this way.

# %% [markdown]
# # Lecture 09: Relational Data
# <div style="border: 1px double black; padding: 10px; margin: 10px">
#
# **Goals for today's lecture:**
# * Learn about [keys](#Keys)
# * Different types of [relations](#Relations) between tables
# * [Commands for joining related tables together](#Outer-joins)
# </div>

# %% [markdown]
# We have already spent a lot of time analyzing the `flights` table. In fact, there are four other tables in `nycflights13` that contain related information about these flights:

# %%
print(airlines)
# Out:
# # A tibble: 16 × 2
#    carrier name
#    <chr>   <chr>
#  1 9E      Endeavor Air Inc.
#  2 AA      American Airlines Inc.
#  3 AS      Alaska Airlines Inc.
#  4 B6      JetBlue Airways
#  5 DL      Delta Air Lines Inc.
#  6 EV      ExpressJet Airlines Inc.
#  7 F9      Frontier Airlines Inc.
#  8 FL      AirTran Airways Corporation
#  9 HA      Hawaiian Airlines Inc.
# 10 MQ      Envoy Air
# 11 OO      SkyWest Airlines Inc.
# 12 UA      United Air Lines Inc.
# 13 US      US Airways Inc.
# 14 VX      Virgin America
# 15 WN      Southwest Airlines Co.
# 16 YV      Mesa Airlines Inc.

# %%
airports
# Out:
#      faa name                                 lat      lon        alt  tz dst
# 1    04G Lansdowne Airport                    41.13047  -80.61958 1044 -5 A
# 2    06A Moton Field Municipal Airport        32.46057  -85.68003  264 -6 A
# 3    06C Schaumburg Regional                  41.98934  -88.10124  801 -6 A
# 4    06N Randall Airport                      41.43191  -74.39156  523 -5 A
# 5    09J Jekyll Island Airport                31.07447  -81.42778   11 -5 A
# 6    0A9 Elizabethton Municipal Airport       36.37122  -82.17342 1593 -5 A
# 7    0G6 Williams County Airport              41.46731  -84.50678  730 -5 A
# 8    0G7 Finger Lakes Regional Airport        42.88356  -76.78123  492 -5 A
# 9    0P2 Shoestring Aviation Airfield         39.79482  -76.64719 1000 -5 U
# 10   0S9 Jefferson County Intl                48.05381 -122.81064  108 -8 A
# 11   0W3 Harford County Airport               39.56684  -76.20240  409 -5 A
# 12   10C Galt Field Airport                   42.40289  -88.37511  875 -6 U
# 13   17G Port Bucyrus-Crawford County Airport 40.78156  -82.97481 1003 -5 A
# 14   19A Jackson County Airport               34.17586  -83.56160  951 -5 U
# 15   1A3 Martin Campbell Field Airport        35.01581  -84.34683 1789 -5 A
# 16   1B9 Mansfield Municipal                  42.00013  -71.19677  122 -5 A
# 17   1C9 Frazier Lake Airpark                 54.01333 -124.76833  152 -8 A
# 18   1CS Clow International Airport           41.69597  -88.12923  670 -6 U
# 19   1G3 Kent State Airport                   41.15139  -81.41511 1134 -5 A
# 20   1G4 Grand Canyon West Airport            35.89990 -113.81567 4813 -7 A
# 21   1H2 Effingham Memorial Airport           39.07000  -88.53400  585 -6 A
# 22   1OH Fortman Airport                      40.55533  -84.38662  885 -5 U
# 23   1RL Point Roberts Airpark                48.97972 -123.07889   10 -8 A
# 24   23M Clarke CO                            32.05170  -88.44340  320 -6 A
# 25   24C Lowell City Airport                  42.95392  -85.34391  681 -5 A
# 26   24J Suwannee County Airport              30.30013  -83.02469  104 -5 A
# 27   25D Forest Lake Airport                  45.24775  -92.99439  925 -6 A
# 28   29D Grove City Airport                   41.14603  -80.16775 1371 -5 A
# 29   2A0 Mark Anton Airport                   35.48625  -84.93108  718 -5 A
# 30   2B2 Plum Island Airport                  42.79536  -70.83944   11 -5 A
# ⋮    ⋮   ⋮                                    ⋮        ⋮          ⋮    ⋮  ⋮
# 1429 X59 Valkaria Municipal                   27.96086  -80.55833   26 -5 A
# 1430 XFL Flagler County Airport               29.28210  -81.12120   33 -5 A
# 1431 XNA NW Arkansas Regional                 36.28187  -94.30681 1287 -6 A
# 1432 XZK Amherst Amtrak Station AMM           42.37500  -72.51139  258 -5 A
# 1433 Y51 Municipal Airport                    43.57936  -90.89647 1292 -6 A
# 1434 Y72 Bloyer Field                         43.97622  -90.48061  966 -6 A
# 1435 YAK Yakutat                              59.30120 -139.39370   33 -9 A
# 1436 YIP Willow Run                           42.23793  -83.53041  716 -5 A
# 1437 YKM Yakima Air Terminal McAllister Field 46.56820 -120.54400 1095 -8 A
# 1438 YKN Chan Gurney                          42.87110  -97.39690 1200 -6 A
# 1439 YNG Youngstown Warren Rgnl               41.26074  -80.67910 1196 -5 A
# 1440 YUM Yuma Mcas Yuma Intl                  32.65658 -114.60598  216 -7 N
# 1441 Z84 Clear                                64.30120 -149.12014  552 -9 A
# 1442 ZBP Penn Station                         39.30722  -76.61556   66 -5 A
# 1443 ZFV Philadelphia 30th St Station         39.95570  -75.18200    0 -5 A
# 1444 ZPH Municipal Airport                    28.22806  -82.15583   90 -5 A
# 1445 ZRA Atlantic City Rail Terminal          39.36650  -74.44200    8 -5 A
# 1446 ZRD Train Station                        37.53430  -77.42945   26 -5 A
# 1447 ZRP Newark Penn Station                  40.73472  -74.16417    0 -5 A
# 1448 ZRT Hartford Union Station               41.76888  -72.68150    0 -5 A
# 1449 ZRZ New Carrollton Rail Station          38.94800  -76.87190   39 -5 A
# 1450 ZSF Springfield Amtrak Station           42.10600  -72.59305   65 -5 A
# 1451 ZSY Scottsdale Airport                   33.62289 -111.91053 1519 -7 A
# 1452 ZTF Stamford Amtrak Station              41.04694  -73.54149    0 -5 A
# 1453 ZTY Boston Back Bay Station              42.34780  -71.07500   20 -5 A
# 1454 ZUN Black Rock                           35.08323 -108.79178 6454 -7 A
# 1455 ZVE New Haven Rail Station               41.29867  -72.92599    7 -5 A
# 1456 ZWI Wilmington Amtrak Station            39.73667  -75.55167    0 -5 A
# 1457 ZWU Washington Union Station             38.89746  -77.00643   76 -5 A
# 1458 ZYP Penn Station                         40.75050  -73.99350   35 -5 A
#      tzone
# 1    America/New_York
# 2    America/Chicago
# 3    America/Chicago
# 4    America/New_York
# 5    America/New_York
# 6    America/New_York
# 7    America/New_York
# 8    America/New_York
# 9    America/New_York
# 10   America/Los_Angeles
# 11   America/New_York
# 12   America/Chicago
# 13   America/New_York
# 14   America/New_York
# 15   America/New_York
# 16   America/New_York
# 17   America/Vancouver
# 18   America/Chicago
# 19   America/New_York
# 20   America/Phoenix
# 21   America/Chicago
# 22   America/New_York
# 23   America/Los_Angeles
# 24   America/Chicago
# 25   America/New_York
# 26   America/New_York
# 27   America/Chicago
# 28   America/New_York
# 29   America/New_York
# 30   America/New_York
# ⋮    ⋮
# 1429 America/New_York
# 1430 America/New_York
# 1431 America/Chicago
# 1432 America/New_York
# 1433 America/Chicago
# 1434 America/Chicago
# 1435 NA
# 1436 America/New_York
# 1437 America/Los_Angeles
# 1438 America/Chicago
# 1439 America/New_York
# 1440 America/Phoenix
# 1441 America/Anchorage
# 1442 America/New_York
# 1443 America/New_York
# 1444 America/New_York
# 1445 America/New_York
# 1446 America/New_York
# 1447 America/New_York
# 1448 America/New_York
# 1449 America/New_York
# 1450 America/New_York
# 1451 America/Phoenix
# 1452 America/New_York
# 1453 America/New_York
# 1454 America/Denver
# 1455 America/New_York
# 1456 America/New_York
# 1457 America/New_York
# 1458 America/New_York

# %%
weather
# Out:
#       origin year month day hour temp  dewp  humid wind_dir wind_speed
# 1     EWR    2013 1     1    1   39.02 26.06 59.37 270      10.35702
# 2     EWR    2013 1     1    2   39.02 26.96 61.63 250       8.05546
# 3     EWR    2013 1     1    3   39.02 28.04 64.43 240      11.50780
# 4     EWR    2013 1     1    4   39.92 28.04 62.21 250      12.65858
# 5     EWR    2013 1     1    5   39.02 28.04 64.43 260      12.65858
# 6     EWR    2013 1     1    6   37.94 28.04 67.21 240      11.50780
# 7     EWR    2013 1     1    7   39.02 28.04 64.43 240      14.96014
# 8     EWR    2013 1     1    8   39.92 28.04 62.21 250      10.35702
# 9     EWR    2013 1     1    9   39.92 28.04 62.21 260      14.96014
# 10    EWR    2013 1     1   10   41.00 28.04 59.65 260      13.80936
# 11    EWR    2013 1     1   11   41.00 26.96 57.06 260      14.96014
# 12    EWR    2013 1     1   13   39.20 28.40 69.67 330      16.11092
# 13    EWR    2013 1     1   14   39.02 24.08 54.68 280      13.80936
# 14    EWR    2013 1     1   15   37.94 24.08 57.04 290       9.20624
# 15    EWR    2013 1     1   16   37.04 19.94 49.62 300      13.80936
# 16    EWR    2013 1     1   17   35.96 19.04 49.83 330      11.50780
# 17    EWR    2013 1     1   18   33.98 15.08 45.43 310      12.65858
# 18    EWR    2013 1     1   19   33.08 12.92 42.84 320      10.35702
# 19    EWR    2013 1     1   20   32.00 15.08 49.19 310      14.96014
# 20    EWR    2013 1     1   21   30.02 12.92 48.48 320      18.41248
# 21    EWR    2013 1     1   22   28.94 12.02 48.69 320      18.41248
# 22    EWR    2013 1     1   23   28.04 10.94 48.15 310      16.11092
# 23    EWR    2013 1     2    0   26.96 10.94 50.34 310      14.96014
# 24    EWR    2013 1     2    1   26.06 10.94 52.25 330      12.65858
# 25    EWR    2013 1     2    2   24.98 10.94 54.65 330      13.80936
# 26    EWR    2013 1     2    3   24.08  8.96 51.93 320      14.96014
# 27    EWR    2013 1     2    4   24.08  8.96 51.93 330      12.65858
# 28    EWR    2013 1     2    5   24.08  8.96 51.93 330       6.90468
# 29    EWR    2013 1     2    6   24.08  8.96 51.93 310       3.45234
# 30    EWR    2013 1     2    7   24.98 10.04 52.50 300       6.90468
# ⋮     ⋮      ⋮    ⋮     ⋮   ⋮    ⋮     ⋮     ⋮     ⋮        ⋮
# 26086 LGA    2013 12    29  13   42.80 37.94 88.76  70      12.65858
# 26087 LGA    2013 12    29  14   41.00 37.94 93.19  60      18.41248
# 26088 LGA    2013 12    29  15   41.00 39.02 92.59  40      13.80936
# 26089 LGA    2013 12    29  16   41.00 37.94 88.76 350       8.05546
# 26090 LGA    2013 12    29  17   44.06 41.00 93.24 350      20.71404
# 26091 LGA    2013 12    29  18   42.08 39.02 88.81 330      14.96014
# 26092 LGA    2013 12    29  19   42.80 37.94 85.13 320      17.26170
# 26093 LGA    2013 12    29  20   42.08 37.94 86.89 320      19.56326
# 26094 LGA    2013 12    29  21   42.80 37.40 82.17 320      16.11092
# 26095 LGA    2013 12    29  22   42.98 37.04 79.38 300       9.20624
# 26096 LGA    2013 12    29  23   42.98 35.06 73.39 310      17.26170
# 26097 LGA    2013 12    30   0   42.08 33.98 72.78 320      11.50780
# 26098 LGA    2013 12    30   1   42.08 33.98 72.78 250       9.20624
# 26099 LGA    2013 12    30   2   41.00 33.98 75.88 240       8.05546
# 26100 LGA    2013 12    30   3   42.98 33.98 70.30 270       9.20624
# 26101 LGA    2013 12    30   4   41.00 33.08 73.19   0       0.00000
# 26102 LGA    2013 12    30   5   42.98 33.08 67.81 250      10.35702
# 26103 LGA    2013 12    30   6   42.98 33.98 70.30 230       6.90468
# 26104 LGA    2013 12    30   7   44.06 35.06 70.42 240      11.50780
# 26105 LGA    2013 12    30   8   44.06 33.98 67.45 260      11.50780
# 26106 LGA    2013 12    30   9   44.06 33.08 65.07 260      13.80936
# 26107 LGA    2013 12    30  10   42.98 33.80 70.28 330      16.11092
# 26108 LGA    2013 12    30  11   41.00 28.40 62.21 340      13.80936
# 26109 LGA    2013 12    30  12   37.94 23.00 54.51 330      21.86482
# 26110 LGA    2013 12    30  13   37.04 21.92 53.97 340      17.26170
# 26111 LGA    2013 12    30  14   35.96 19.94 51.78 340      13.80936
# 26112 LGA    2013 12    30  15   33.98 17.06 49.51 330      17.26170
# 26113 LGA    2013 12    30  16   32.00 15.08 49.19 340      14.96014
# 26114 LGA    2013 12    30  17   30.92 12.92 46.74 320      17.26170
# 26115 LGA    2013 12    30  18   28.94 10.94 46.41 330      18.41248
#       wind_gust precip pressure visib time_hour
# 1           NA  0      1012.0   10    2013-01-01 01:00:00
# 2           NA  0      1012.3   10    2013-01-01 02:00:00
# 3           NA  0      1012.5   10    2013-01-01 03:00:00
# 4           NA  0      1012.2   10    2013-01-01 04:00:00
# 5           NA  0      1011.9   10    2013-01-01 05:00:00
# 6           NA  0      1012.4   10    2013-01-01 06:00:00
# 7           NA  0      1012.2   10    2013-01-01 07:00:00
# 8           NA  0      1012.2   10    2013-01-01 08:00:00
# 9           NA  0      1012.7   10    2013-01-01 09:00:00
# 10          NA  0      1012.4   10    2013-01-01 10:00:00
# 11          NA  0      1011.4   10    2013-01-01 11:00:00
# 12          NA  0          NA   10    2013-01-01 13:00:00
# 13          NA  0      1010.8   10    2013-01-01 14:00:00
# 14          NA  0      1011.9   10    2013-01-01 15:00:00
# 15    20.71404  0      1012.1   10    2013-01-01 16:00:00
# 16          NA  0      1013.2   10    2013-01-01 17:00:00
# 17    25.31716  0      1014.1   10    2013-01-01 18:00:00
# 18          NA  0      1014.4   10    2013-01-01 19:00:00
# 19          NA  0      1015.2   10    2013-01-01 20:00:00
# 20    26.46794  0      1016.0   10    2013-01-01 21:00:00
# 21    25.31716  0      1016.5   10    2013-01-01 22:00:00
# 22          NA  0      1016.4   10    2013-01-01 23:00:00
# 23    25.31716  0      1016.3   10    2013-01-02 00:00:00
# 24    24.16638  0      1016.3   10    2013-01-02 01:00:00
# 25          NA  0      1017.0   10    2013-01-02 02:00:00
# 26          NA  0      1016.6   10    2013-01-02 03:00:00
# 27          NA  0      1016.9   10    2013-01-02 04:00:00
# 28          NA  0      1016.9   10    2013-01-02 05:00:00
# 29          NA  0      1017.2   10    2013-01-02 06:00:00
# 30          NA  0      1017.6   10    2013-01-02 07:00:00
# ⋮     ⋮         ⋮      ⋮        ⋮     ⋮
# 26086       NA  0.19       NA    2.50 2013-12-29 13:00:00
# 26087       NA  0.21       NA    1.75 2013-12-29 14:00:00
# 26088       NA  0.37    999.9    1.50 2013-12-29 15:00:00
# 26089 23.01560  0.28    998.7    1.50 2013-12-29 16:00:00
# 26090       NA  0.04       NA    5.00 2013-12-29 17:00:00
# 26091       NA  0.00    997.2    3.00 2013-12-29 18:00:00
# 26092       NA  0.00       NA    8.00 2013-12-29 19:00:00
# 26093       NA  0.00       NA   10.00 2013-12-29 20:00:00
# 26094       NA  0.00       NA   10.00 2013-12-29 21:00:00
# 26095       NA  0.00   1003.8   10.00 2013-12-29 22:00:00
# 26096 24.16638  0.00   1005.1   10.00 2013-12-29 23:00:00
# 26097       NA  0.00   1005.9   10.00 2013-12-30 00:00:00
# 26098       NA  0.00   1007.6   10.00 2013-12-30 01:00:00
# 26099       NA  0.00   1008.3   10.00 2013-12-30 02:00:00
# 26100       NA  0.00   1008.2   10.00 2013-12-30 03:00:00
# 26101       NA  0.00   1008.9   10.00 2013-12-30 04:00:00
# 26102       NA  0.00   1009.2   10.00 2013-12-30 05:00:00
# 26103       NA  0.00   1010.8   10.00 2013-12-30 06:00:00
# 26104       NA  0.00   1011.9   10.00 2013-12-30 07:00:00
# 26105       NA  0.00   1012.9   10.00 2013-12-30 08:00:00
# 26106       NA  0.00   1013.7   10.00 2013-12-30 09:00:00
# 26107       NA  0.00       NA   10.00 2013-12-30 10:00:00
# 26108 23.01560  0.00       NA   10.00 2013-12-30 11:00:00
# 26109 27.61872  0.00   1015.7   10.00 2013-12-30 12:00:00
# 26110 20.71404  0.00   1016.5   10.00 2013-12-30 13:00:00
# 26111 21.86482  0.00   1017.1   10.00 2013-12-30 14:00:00
# 26112 21.86482  0.00   1018.8   10.00 2013-12-30 15:00:00
# 26113 23.01560  0.00   1019.5   10.00 2013-12-30 16:00:00
# 26114       NA  0.00   1019.9   10.00 2013-12-30 17:00:00
# 26115       NA  0.00   1020.9   10.00 2013-12-30 18:00:00

# %%
print(weather)
# Out:
# # A tibble: 26,115 × 15
#    origin  year month   day  hour  temp  dewp humid wind_dir wind_speed wind_g…¹
#    <chr>  <int> <int> <int> <int> <dbl> <dbl> <dbl>    <dbl>      <dbl>    <dbl>
#  1 EWR     2013     1     1     1  39.0  26.1  59.4      270      10.4        NA
#  2 EWR     2013     1     1     2  39.0  27.0  61.6      250       8.06       NA
#  3 EWR     2013     1     1     3  39.0  28.0  64.4      240      11.5        NA
#  4 EWR     2013     1     1     4  39.9  28.0  62.2      250      12.7        NA
#  5 EWR     2013     1     1     5  39.0  28.0  64.4      260      12.7        NA
#  6 EWR     2013     1     1     6  37.9  28.0  67.2      240      11.5        NA
#  7 EWR     2013     1     1     7  39.0  28.0  64.4      240      15.0        NA
#  8 EWR     2013     1     1     8  39.9  28.0  62.2      250      10.4        NA
#  9 EWR     2013     1     1     9  39.9  28.0  62.2      260      15.0        NA
# 10 EWR     2013     1     1    10  41    28.0  59.6      260      13.8        NA
# # … with 26,105 more rows, 4 more variables: precip <dbl>, pressure <dbl>,
# #   visib <dbl>, time_hour <dttm>, and abbreviated variable name ¹​wind_gust

# %% [markdown]
# Together these four tables form a *relational database*. The relationships can be graphed like so:
# ![table relationships](http://r4ds.had.co.nz/diagrams/relational-nycflights.png)

# %% [markdown]
# The particular relationships in this database are:
# - `flights` connects to `planes` via `tailnum`.
# - `flights` connects to `airlines` via `carrier`.
# - `flights` connects to `airports` twice: via `origin` and `dest`.
# - `flights` connects to `weather` via `origin` (the location), and `year`, `month`, `day` and `hour`.

# %% [markdown]
# ## Keys
# The "key" to understanding relational databases is... keys.

# %% [markdown]
# ### Primary Key
# A *primary key* is a variable (or set of variables) that uniquely identifies an observation in its own table: there is **at most** one row in the table that corresponds to any setting of the columns which comprise the key.

# %% [markdown]
# In the `planes` table, each airplane is identified by its `tailnum`:

# %%
print(planes)
# Out:
# # A tibble: 3,322 × 9
#    tailnum  year type                   manuf…¹ model engines seats speed engine
#    <chr>   <int> <chr>                  <chr>   <chr>   <int> <int> <int> <chr>
#  1 N10156   2004 Fixed wing multi engi… EMBRAER EMB-…       2    55    NA Turbo…
#  2 N102UW   1998 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  3 N103US   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  4 N104UW   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  5 N10575   2002 Fixed wing multi engi… EMBRAER EMB-…       2    55    NA Turbo…
#  6 N105UW   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  7 N107US   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  8 N108UW   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
#  9 N109UW   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
# 10 N110UW   1999 Fixed wing multi engi… AIRBUS… A320…       2   182    NA Turbo…
# # … with 3,312 more rows, and abbreviated variable name ¹​manufacturer

# %% [markdown]
# The tail number of an airplane is assigned by a government agency and is unique: no two planes can have the same tail number. Thus, `tailnum` should be a primary key in this table.
#
# To check that one or more variables constitutes a primary key, we can group by those variables and then check that the number of distinct values equals the number of rows in the data set:

# %%
# planes %>% print
planes  %>% summarize(n = n(), nd = n_distinct(tailnum))
# Out:
#   n    nd
# 1 3322 3322

# %% [markdown]
# Compare with `flights`, where tailnum does *not* uniquely identify each row. (There are many flights present for the same airplane.)

# %%
distinct(flights, tailnum) %>% print
# Out:
# # A tibble: 4,044 x 1
#    tailnum
#    <chr>
#  1 N14228
#  2 N24211
#  3 N619AA
#  4 N804JB
#  5 N668DN
#  6 N39463
#  7 N516JB
#  8 N829AS
#  9 N593JB
# 10 N3ALAA
# # … with 4,034 more rows

# %% [markdown]
# What is the primary key for the `flights` table?

# %%
count(flights, year, month, day, dep_time, tailnum) %>% filter(n > 1, !is.na(tailnum))
# Out:
#     year month day dep_time tailnum n
# 1   2013 1      2  NA       N10575  2
# 2   2013 1     16  NA       N12195  2
# 3   2013 1     18  NA       N12166  2
# 4   2013 1     18  NA       N12957  2
# 5   2013 1     25  NA       N13133  2
# 6   2013 1     25  NA       N13968  2
# 7   2013 1     26  NA       N832MQ  2
# 8   2013 1     28  NA       N10156  2
# 9   2013 1     28  NA       N11548  2
# 10  2013 1     28  NA       N13908  2
# 11  2013 1     28  NA       N13969  3
# 12  2013 1     28  NA       N14125  2
# 13  2013 1     28  NA       N17159  2
# 14  2013 1     28  NA       N18102  2
# 15  2013 1     28  NA       N24128  2
# 16  2013 1     28  NA       N26549  2
# 17  2013 1     30  NA       N11551  2
# 18  2013 1     30  NA       N12996  2
# 19  2013 1     30  NA       N13538  2
# 20  2013 1     30  NA       N13994  2
# 21  2013 1     31  NA       N11140  2
# 22  2013 1     31  NA       N11193  2
# 23  2013 1     31  NA       N12163  2
# 24  2013 1     31  NA       N14959  2
# 25  2013 1     31  NA       N15572  2
# 26  2013 1     31  NA       N15986  2
# 27  2013 1     31  NA       N16561  2
# 28  2013 2      1  NA       N12996  2
# 29  2013 2      4  NA       N11565  2
# 30  2013 2      4  NA       N16951  2
# ⋮   ⋮    ⋮     ⋮   ⋮        ⋮       ⋮
# 431 2013 12    10  NA       N6EAMQ  2
# 432 2013 12    10  NA       N710EV  2
# 433 2013 12    10  NA       N827MQ  2
# 434 2013 12    10  NA       N935WN  2
# 435 2013 12    14  NA       N11548  4
# 436 2013 12    14  NA       N12569  2
# 437 2013 12    14  NA       N12996  3
# 438 2013 12    14  NA       N13538  2
# 439 2013 12    14  NA       N13988  2
# 440 2013 12    14  NA       N13992  2
# 441 2013 12    14  NA       N14542  2
# 442 2013 12    14  NA       N16951  2
# 443 2013 12    14  NA       N16987  2
# 444 2013 12    14  NA       N31131  3
# 445 2013 12    14  NA       N539MQ  2
# 446 2013 12    14  NA       N829AS  2
# 447 2013 12    15  NA       N13989  2
# 448 2013 12    15  NA       N661JB  2
# 449 2013 12    16  NA       N816MQ  2
# 450 2013 12    17  NA       N13566  2
# 451 2013 12    17  NA       N13949  2
# 452 2013 12    17  NA       N14186  2
# 453 2013 12    17  NA       N14570  2
# 454 2013 12    17  NA       N14904  2
# 455 2013 12    17  NA       N16918  2
# 456 2013 12    17  NA       N16981  2
# 457 2013 12    17  NA       N813MQ  2
# 458 2013 12    20  NA       N16112  2
# 459 2013 12    26  NA       N877AS  2
# 460 2013 12    29  NA       N231JB  2

# %% [markdown]
# We might guess that `year`, `month`, `day`, and `tailnum` are sufficient to identify each row in `flights`, but this is not true:

# %%
flights %>% summarize(n=n(), nd=n_distinct(year, month, day, tailnum))
# Out:
#   n      nd
# 1 336776 251727

# %% [markdown]
# In fact, even restricting to the exact *minute* that an airplane departed is not sufficient:

# %%
flights %>% summarize(n=n(), nd=n_distinct(tailnum, time_hour, minute))
# Out:
#   n      nd
# 1 336776 336367

# %% [markdown]
# This says that there are certain airplanes that are marked as having departed more than once in the same year, month, day, hour and minute. We can inspect these rows as follows:

# %%
group_by(flights, tailnum, time_hour, minute) %>% count %>% filter(n>1) %>% arrange(tailnum, time_hour) %>% print
# Out:
# # A tibble: 298 x 4
# # Groups:   tailnum, time_hour, minute [298]
#    tailnum time_hour           minute     n
#    <chr>   <dttm>               <dbl> <int>
#  1 N11119  2013-06-10 16:00:00     55     2
#  2 N11192  2013-08-26 08:00:00     30     2
#  3 N12563  2013-02-04 16:00:00     19     2
#  4 N12564  2013-01-13 20:00:00      0     2
#  5 N12900  2013-07-10 21:00:00     29     2
#  6 N13969  2013-01-28 07:00:00     59     2
#  7 N14148  2013-03-12 06:00:00     30     2
#  8 N14558  2013-04-19 13:00:00     29     2
#  9 N14916  2013-02-11 13:00:00     15     2
# 10 N14974  2013-07-26 06:00:00     30     2
# # … with 288 more rows

# %% [markdown]
# These likely indicate data entry errors.

# %% [markdown]
# ## 🤔 Quiz
#
# What column(s) constitute a primary key in the `planes` table?
#
# <ol style="list-style-type: upper-alpha;">
#     <li><code>tailnum</code> only</li>
#     <li><code>tailnum</code> and <code>model</code></li>
#     <li><code>model</code> only</li>
#     <li><code>model</code> and <code>engines</code></li>
#     <li><code>model</code>, <code>engines</code>, and <code>year</code></li>
# </ol>

# %%
# primary key for planes

distinct(planes, model, engines, year)
# Out:
#     model              engines year
# 1   EMB-145XR          2       2004
# 2   A320-214           2       1998
# 3   A320-214           2       1999
# 4   EMB-145LR          2       2002
# 5   EMB-145XR          2       2002
# 6   EMB-145XR          2       2003
# 7   EMB-145XR          2       2005
# 8   EMB-145XR          2       2006
# 9   737-824            2       2000
# 10  EMB-145LR          2       2001
# 11  A320-214           2       2000
# 12  767-332            2       1998
# 13  757-224            2       1994
# 14  757-224            2       1995
# 15  757-224            2       1996
# 16  757-224            2       1998
# 17  767-332            2       1987
# 18  737-824            2       1998
# 19  737-824            2       1999
# 20  A320-214           2       2009
# 21  A320-214           2       2010
# 22  EMB-145LR          2       2000
# 23  EMB-145LR          2       1998
# 24  EMB-145LR          2       1999
# 25  757-224            2       1999
# 26  CL-600-2D24        2       2009
# 27  767-332            2       1991
# 28  737-724            2       1998
# 29  737-724            2       1999
# 30  757-224            2       1997
# ⋮   ⋮                  ⋮       ⋮
# 424 MD-90-30           2       1995
# 425 MD-88              2       1987
# 426 737-7H4            2       2008
# 427 MYSTERE FALCON 900 3       1986
# 428 A319-112           2       2002
# 429 MD-90-30           2       1996
# 430 CL-600-2D24        2       2004
# 431 MD-88              2       1993
# 432 MD-88              2       1988
# 433 CL-600-2D24        2         NA
# 434 MD-90-30           2       1997
# 435 MD-90-30           2       1998
# 436 MD-90-30           2         NA
# 437 CL-600-2D24        2       2005
# 438 737-7H4            2       2009
# 439 MD-88              2       1989
# 440 717-200            2       1999
# 441 717-200            2       2006
# 442 757-2B7            2       1995
# 443 A319-112           2       2005
# 444 737-7H4            2       2010
# 445 A319-112           2       2006
# 446 MD-88              2       1990
# 447 A319-112           2       2009
# 448 A319-112           2       2010
# 449 737-7H4            2       2011
# 450 MD-90-30           2       1999
# 451 MD-90-30           2       2000
# 452 MD-88              2       1991
# 453 717-200            2         NA

# %% [markdown]
# ## 🤔 Quiz
#
# What column(s) constitute a primary key in the `mpg` table?
#
# <ol style="list-style-type: upper-alpha;">
#     <li><code>manufacturer</code> and <code>model</code></li>
#     <li><code>manufacturer</code>, <code>year</code>, and <code>model</code></li>
#     <li><code>manufacturer</code>, <code>year</code>, <code>displ</code>, and <code>model</code></li>
#     <li><code>manufacturer</code>, <code>year</code>, <code>displ</code>, <code>trans</code>, and <code>model</code></li>
#     <li>None of these</li>
# </ol>

# %%
# primary key in mpg 

count(mpg, across(everything()))
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 4   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 9   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 10  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# 11  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 12  audi         a4 quattro         2.8   1999 6   auto(l5)   4   15  25  p
# 13  audi         a4 quattro         2.8   1999 6   manual(m5) 4   17  25  p
# 14  audi         a4 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 15  audi         a4 quattro         3.1   2008 6   manual(m6) 4   15  25  p
# 16  audi         a6 quattro         2.8   1999 6   auto(l5)   4   15  24  p
# 17  audi         a6 quattro         3.1   2008 6   auto(s6)   4   17  25  p
# 18  audi         a6 quattro         4.2   2008 8   auto(s6)   4   16  23  p
# 19  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   11  15  e
# 20  chevrolet    c1500 suburban 2wd 5.3   2008 8   auto(l4)   r   14  20  r
# 21  chevrolet    c1500 suburban 2wd 5.7   1999 8   auto(l4)   r   13  17  r
# 22  chevrolet    c1500 suburban 2wd 6.0   2008 8   auto(l4)   r   12  17  r
# 23  chevrolet    corvette           5.7   1999 8   auto(l4)   r   15  23  p
# 24  chevrolet    corvette           5.7   1999 8   manual(m6) r   16  26  p
# 25  chevrolet    corvette           6.2   2008 8   auto(s6)   r   15  25  p
# 26  chevrolet    corvette           6.2   2008 8   manual(m6) r   16  26  p
# 27  chevrolet    corvette           7.0   2008 8   manual(m6) r   15  24  p
# 28  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   11  14  e
# 29  chevrolet    k1500 tahoe 4wd    5.3   2008 8   auto(l4)   4   14  19  r
# 30  chevrolet    k1500 tahoe 4wd    5.7   1999 8   auto(l4)   4   11  15  r
# ⋮   ⋮            ⋮                  ⋮     ⋮    ⋮   ⋮          ⋮   ⋮   ⋮   ⋮
# 196 toyota       toyota tacoma 4wd  3.4   1999 6   manual(m5) 4   15  17  r
# 197 toyota       toyota tacoma 4wd  4.0   2008 6   auto(l5)   4   16  20  r
# 198 toyota       toyota tacoma 4wd  4.0   2008 6   manual(m6) 4   15  18  r
# 199 volkswagen   gti                2.0   1999 4   auto(l4)   f   19  26  r
# 200 volkswagen   gti                2.0   1999 4   manual(m5) f   21  29  r
# 201 volkswagen   gti                2.0   2008 4   auto(s6)   f   22  29  p
# 202 volkswagen   gti                2.0   2008 4   manual(m6) f   21  29  p
# 203 volkswagen   gti                2.8   1999 6   manual(m5) f   17  24  r
# 204 volkswagen   jetta              1.9   1999 4   manual(m5) f   33  44  d
# 205 volkswagen   jetta              2.0   1999 4   auto(l4)   f   19  26  r
# 206 volkswagen   jetta              2.0   1999 4   manual(m5) f   21  29  r
# 207 volkswagen   jetta              2.0   2008 4   auto(s6)   f   22  29  p
# 208 volkswagen   jetta              2.0   2008 4   manual(m6) f   21  29  p
# 209 volkswagen   jetta              2.5   2008 5   auto(s6)   f   21  29  r
# 210 volkswagen   jetta              2.5   2008 5   manual(m5) f   21  29  r
# 211 volkswagen   jetta              2.8   1999 6   auto(l4)   f   16  23  r
# 212 volkswagen   jetta              2.8   1999 6   manual(m5) f   17  24  r
# 213 volkswagen   new beetle         1.9   1999 4   auto(l4)   f   29  41  d
# 214 volkswagen   new beetle         1.9   1999 4   manual(m5) f   35  44  d
# 215 volkswagen   new beetle         2.0   1999 4   auto(l4)   f   19  26  r
# 216 volkswagen   new beetle         2.0   1999 4   manual(m5) f   21  29  r
# 217 volkswagen   new beetle         2.5   2008 5   auto(s6)   f   20  29  r
# 218 volkswagen   new beetle         2.5   2008 5   manual(m5) f   20  28  r
# 219 volkswagen   passat             1.8   1999 4   auto(l5)   f   18  29  p
# 220 volkswagen   passat             1.8   1999 4   manual(m5) f   21  29  p
# 221 volkswagen   passat             2.0   2008 4   auto(s6)   f   19  28  p
# 222 volkswagen   passat             2.0   2008 4   manual(m6) f   21  29  p
# 223 volkswagen   passat             2.8   1999 6   auto(l5)   f   16  26  p
# 224 volkswagen   passat             2.8   1999 6   manual(m5) f   18  26  p
# 225 volkswagen   passat             3.6   2008 6   auto(s6)   f   17  26  p
#     class      n
# 1   compact    1
# 2   compact    1
# 3   compact    1
# 4   compact    1
# 5   compact    1
# 6   compact    1
# 7   compact    1
# 8   compact    1
# 9   compact    1
# 10  compact    1
# 11  compact    1
# 12  compact    1
# 13  compact    1
# 14  compact    1
# 15  compact    1
# 16  midsize    1
# 17  midsize    1
# 18  midsize    1
# 19  suv        1
# 20  suv        2
# 21  suv        1
# 22  suv        1
# 23  2seater    1
# 24  2seater    1
# 25  2seater    1
# 26  2seater    1
# 27  2seater    1
# 28  suv        1
# 29  suv        1
# 30  suv        1
# ⋮   ⋮          ⋮
# 196 pickup     1
# 197 pickup     1
# 198 pickup     1
# 199 compact    1
# 200 compact    1
# 201 compact    1
# 202 compact    1
# 203 compact    1
# 204 compact    1
# 205 compact    1
# 206 compact    1
# 207 compact    1
# 208 compact    1
# 209 compact    1
# 210 compact    1
# 211 compact    1
# 212 compact    1
# 213 subcompact 1
# 214 subcompact 1
# 215 subcompact 1
# 216 subcompact 1
# 217 subcompact 1
# 218 subcompact 1
# 219 midsize    1
# 220 midsize    1
# 221 midsize    1
# 222 midsize    1
# 223 midsize    1
# 224 midsize    1
# 225 midsize    1

# %% [markdown]
# ## Relations
# A primary key and the corresponding foreign key in another table form a *relation*. Relations come in several forms:
# - *One-to-many*. (Most common). For example, each flight has one plane, but each plane has many flights.
# - *Many-to-many*: For example, each airline flies to many airports; each airport hosts many airlines.
# - *One-to-one*. Each row in one table corresponds uniquely to a row in a second table. This is relatively uncommon because you could just as easily combine the two tables into one.

# %%
x = tribble(
  ~key, ~val_x,
     1, "x1",
     2, "x2",
     3, "x3"
)
y = tribble(
  ~key, ~val_y,
     1, "y1",
     2, "y2",
     4, "y3"
)

# %%
x
y
# Out:
#   key val_x
# 1 1   x1
# 2 2   x2
# 3 3   x3
#   key val_y
# 1 1   y1
# 2 2   y2
# 3 4   y3

# %% [markdown]
# ## Joins
# Joins are the way the we combine or "merge" two data tables based on keys.
# To understand how joins work we'll study these two simple tables:
# ![simple tables](http://r4ds.had.co.nz/diagrams/join-setup.png)

# %% [markdown]
# ### Inner joins
# Inner joins match a pair of observations whenever their keys are equal:
# ![match example](https://r4ds.hadley.nz/diagrams/join/inner.png)

# %%
inner_join(x, y)
# Out:
# Joining with `by = join_by(key)`
#   key val_x val_y
# 1 1   x1    y1
# 2 2   x2    y2

# %% [markdown]
# Note that there is no row for `key=3` or `key=4`: with an inner join, unmatched rows are not included in the result. For this reason, we do not as often use inner joins for data analysis since you can easily lose observations.

# %% [markdown]
# ### Outer joins
# An outer join keeps observations that appear in at least one of the tables. There are three types of outer joins:
# - A left join keeps all observations in x.
# - A right join keeps all observations in y.
# - A full join keeps all observations in x and y.

# %% [markdown]
# ![match example](https://r4ds.hadley.nz/diagrams/join/left.png)

# %% [markdown]
# ![match example](https://r4ds.hadley.nz/diagrams/join/right.png)

# %% [markdown]
# ![match example](https://r4ds.hadley.nz/diagrams/join/full.png)

# %% [markdown]
# Left joins are the most common. Use them to look up data in another table, but preserve your original observations when there in cases where the other table does not have a match.

# %% [markdown]
# ### Example
# The `flights` table has a `carrier` column which is a two-letter code for the airline. The `airlines` table maps these code to recognizable airline names.
#
# How many flighs are there per carrier in the dataset?

# %%
# flights per carrier

count(flights, carrier) %>% select(car = carrier, n) %>% left_join(airlines, by = c("car"="carrier"))
# Out:
#    car n     name
# 1  9E  18460 Endeavor Air Inc.
# 2  AA  32729 American Airlines Inc.
# 3  AS    714 Alaska Airlines Inc.
# 4  B6  54635 JetBlue Airways
# 5  DL  48110 Delta Air Lines Inc.
# 6  EV  54173 ExpressJet Airlines Inc.
# 7  F9    685 Frontier Airlines Inc.
# 8  FL   3260 AirTran Airways Corporation
# 9  HA    342 Hawaiian Airlines Inc.
# 10 MQ  26397 Envoy Air
# 11 OO     32 SkyWest Airlines Inc.
# 12 UA  58665 United Air Lines Inc.
# 13 US  20536 US Airways Inc.
# 14 VX   5162 Virgin America
# 15 WN  12275 Southwest Airlines Co.
# 16 YV    601 Mesa Airlines Inc.

# %% [markdown]
# ## 🤔 Quiz
#
# How many flights departing from EWR were operated by Envoy Air?
#
# <ol style="list-style-type: upper-alpha;">
#     <li>46087</li>
#     <li>26397</li>
#     <li>2276</li>
#     <li>18460</li>
#     <li>43939</li>
# </ol>

# %%
# envoy flights from ewr

filter(flights, origin == "EWR") %>% count(carrier) %>% select(car = carrier, n)

filter(airlines, carrier == "MQ")
# Out:
#    car n
# 1  9E   1268
# 2  AA   3487
# 3  AS    714
# 4  B6   6557
# 5  DL   4342
# 6  EV  43939
# 7  MQ   2276
# 8  OO      6
# 9  UA  46087
# 10 US   4405
# 11 VX   1566
# 12 WN   6188
#   carrier name
# 1 MQ      Envoy Air

# %% [markdown]
# ### Duplicate keys
# Although we have defined keys in terms of uniqueness, it's not required that a key be unique. There are several possibilities:

# %% [markdown]
# ##### One table has duplicate keys
# This is useful when you want to add in additional information as there is typically a one-to-many relationship.
# ![duplicate keys](http://r4ds.had.co.nz/diagrams/join-one-to-many.png)

# %% [markdown]
# In fact, we already saw an example of this above when we joined `planes` to `flights`: each plane belongs to potentially many flights.

# %% [markdown]
# ### Exercise
# What is the most common model of airplane used by each carrier?

# %%
# most common model

left_join(flights, planes, by="tailnum") %>% count(carrier, model) %>% group_by(carrier) %>% top_n(1)

# planes
# Out:
# Selecting by n
#    carrier model       n
# 1  9E      CL-600-2D24 10580
# 2  AA      NA          22558
# 3  AS      737-890       346
# 4  B6      A320-232    34063
# 5  DL      MD-88       10191
# 6  EV      EMB-145LR   28027
# 7  F9      A320-214      617
# 8  FL      717-200      2774
# 9  HA      A330-243      342
# 10 MQ      NA          25397
# 11 OO      CL-600-2C10    25
# 12 UA      737-824     13809
# 13 US      A319-112     5844
# 14 VX      A320-214     4859
# 15 WN      737-7H4     10389
# 16 YV      CL-600-2C10   311

# %% [markdown]
# ##### Both tables have duplicate keys
# This represents a many-to-many join and is usually an error since they key does not uniquely identify observations in either table. Joining duplicated keys results in the Cartesian product of all the possible matches:
# ![cartesian](https://r4ds.hadley.nz/diagrams/join/full.png)

# %% [markdown]
# Be careful when doing many-to-many merges. It's possible to generate huge tables by accident and crash R.

# %% [markdown]
# ## 🤔 Quiz
# To understand what the weather conditions were when each flight departed, I will join the weather table to the first 100 rows of the flights table using the command
#
# ```
# flights %>% slice(1:100) %>% left_join(weather, by=c("origin", "hour"))
# ```
#
# How many rows does the resulting table have?
#
# <ol style="list-style-type: upper-alpha;">
#     <li>100</li>
#     <li>36344</li>
#     <li>336776</li>
#     <li>Zero</li>
#     <li><code>NA</code></li>
# </ol>

# %%
flights %>% slice(1:100) %>% left_join(weather, by=c("origin", "hour"))
# Out:
# Warning message in left_join(., weather, by = c("origin", "hour")):
# “Each row in `x` is expected to match at most 1 row in `y`.
# ℹ Row 1 of `x` matches multiple rows.
# ℹ If multiple matches are expected, set `multiple = "all"` to silence this warning.”
#       year.x month.x day.x dep_time sched_dep_time dep_delay arr_time
# 1     2013   1       1     517      515            2         830
# 2     2013   1       1     517      515            2         830
# 3     2013   1       1     517      515            2         830
# 4     2013   1       1     517      515            2         830
# 5     2013   1       1     517      515            2         830
# 6     2013   1       1     517      515            2         830
# 7     2013   1       1     517      515            2         830
# 8     2013   1       1     517      515            2         830
# 9     2013   1       1     517      515            2         830
# 10    2013   1       1     517      515            2         830
# 11    2013   1       1     517      515            2         830
# 12    2013   1       1     517      515            2         830
# 13    2013   1       1     517      515            2         830
# 14    2013   1       1     517      515            2         830
# 15    2013   1       1     517      515            2         830
# 16    2013   1       1     517      515            2         830
# 17    2013   1       1     517      515            2         830
# 18    2013   1       1     517      515            2         830
# 19    2013   1       1     517      515            2         830
# 20    2013   1       1     517      515            2         830
# 21    2013   1       1     517      515            2         830
# 22    2013   1       1     517      515            2         830
# 23    2013   1       1     517      515            2         830
# 24    2013   1       1     517      515            2         830
# 25    2013   1       1     517      515            2         830
# 26    2013   1       1     517      515            2         830
# 27    2013   1       1     517      515            2         830
# 28    2013   1       1     517      515            2         830
# 29    2013   1       1     517      515            2         830
# 30    2013   1       1     517      515            2         830
# ⋮     ⋮      ⋮       ⋮     ⋮        ⋮              ⋮         ⋮
# 36315 2013   1       1     752      759            -7        955
# 36316 2013   1       1     752      759            -7        955
# 36317 2013   1       1     752      759            -7        955
# 36318 2013   1       1     752      759            -7        955
# 36319 2013   1       1     752      759            -7        955
# 36320 2013   1       1     752      759            -7        955
# 36321 2013   1       1     752      759            -7        955
# 36322 2013   1       1     752      759            -7        955
# 36323 2013   1       1     752      759            -7        955
# 36324 2013   1       1     752      759            -7        955
# 36325 2013   1       1     752      759            -7        955
# 36326 2013   1       1     752      759            -7        955
# 36327 2013   1       1     752      759            -7        955
# 36328 2013   1       1     752      759            -7        955
# 36329 2013   1       1     752      759            -7        955
# 36330 2013   1       1     752      759            -7        955
# 36331 2013   1       1     752      759            -7        955
# 36332 2013   1       1     752      759            -7        955
# 36333 2013   1       1     752      759            -7        955
# 36334 2013   1       1     752      759            -7        955
# 36335 2013   1       1     752      759            -7        955
# 36336 2013   1       1     752      759            -7        955
# 36337 2013   1       1     752      759            -7        955
# 36338 2013   1       1     752      759            -7        955
# 36339 2013   1       1     752      759            -7        955
# 36340 2013   1       1     752      759            -7        955
# 36341 2013   1       1     752      759            -7        955
# 36342 2013   1       1     752      759            -7        955
# 36343 2013   1       1     752      759            -7        955
# 36344 2013   1       1     752      759            -7        955
#       sched_arr_time arr_delay carrier ⋯ temp  dewp  humid  wind_dir wind_speed
# 1     819            11        UA      ⋯ 39.02 28.04  64.43 260      12.65858
# 2     819            11        UA      ⋯ 24.08  8.96  51.93 330       6.90468
# 3     819            11        UA      ⋯ 26.06 15.08  62.70 290       5.75390
# 4     819            11        UA      ⋯ 30.92 21.02  66.34 240      11.50780
# 5     819            11        UA      ⋯ 32.00 17.06  53.60 240      12.65858
# 6     819            11        UA      ⋯ 33.80 30.20  88.37 210       5.75390
# 7     819            11        UA      ⋯ 35.06 26.96  72.03 290       4.60312
# 8     819            11        UA      ⋯ 28.94 24.08  81.80 210       4.60312
# 9     819            11        UA      ⋯ 35.06 28.94  78.13   0       0.00000
# 10    819            11        UA      ⋯ 41.00 26.06  54.97 300      12.65858
# 11    819            11        UA      ⋯ 37.04 24.98  61.35   0       0.00000
# 12    819            11        UA      ⋯ 44.96 44.60 100.00 360       9.20624
# 13    819            11        UA      ⋯ 44.60 44.60 100.00 170       3.45234
# 14    819            11        UA      ⋯ 48.92 48.92 100.00 140       3.45234
# 15    819            11        UA      ⋯ 35.96 30.92  81.72 360      10.35702
# 16    819            11        UA      ⋯ 32.00 32.00 100.00  20       5.75390
# 17    819            11        UA      ⋯ 39.02 30.02  69.86 270       9.20624
# 18    819            11        UA      ⋯ 30.02 15.98  55.42 340      12.65858
# 19    819            11        UA      ⋯ 30.02 19.04  63.24 220      10.35702
# 20    819            11        UA      ⋯ 39.02 28.94  66.85 200       9.20624
# 21    819            11        UA      ⋯ 26.96  8.96  46.08 250       6.90468
# 22    819            11        UA      ⋯ 19.94  6.08  54.30 290      14.96014
# 23    819            11        UA      ⋯ 10.94 -4.00  50.19 270      10.35702
# 24    819            11        UA      ⋯ 14.00  3.02  61.00 350       5.75390
# 25    819            11        UA      ⋯ 12.92 -0.04  55.47 280      13.80936
# 26    819            11        UA      ⋯ 15.08  8.96  76.27 300       9.20624
# 27    819            11        UA      ⋯ 19.04  8.06  61.72 270       6.90468
# 28    819            11        UA      ⋯ 28.04 15.98  60.10   0       0.00000
# 29    819            11        UA      ⋯ 37.94 35.96  92.49   0       0.00000
# 30    819            11        UA      ⋯ 39.92 39.92 100.00  20       4.60312
# ⋮     ⋮              ⋮         ⋮       ⋱ ⋮     ⋮     ⋮      ⋮        ⋮
# 36315 959            -4        US      ⋯ 39.02 30.02 69.86   30       4.60312
# 36316 959            -4        US      ⋯ 42.08 35.06 75.98   50       5.75390
# 36317 959            -4        US      ⋯ 41.00 33.98 75.88  320       4.60312
# 36318 959            -4        US      ⋯ 39.92 30.92 69.96   60       9.20624
# 36319 959            -4        US      ⋯ 46.94 44.96 92.78   40       3.45234
# 36320 959            -4        US      ⋯ 53.60 50.00 93.55  340      10.35702
# 36321 959            -4        US      ⋯ 37.04 30.02 75.50  330       9.20624
# 36322 959            -4        US      ⋯ 30.02 15.08 53.29   10       4.60312
# 36323 959            -4        US      ⋯ 35.60 33.80 93.08   40      14.96014
# 36324 959            -4        US      ⋯ 35.06 30.02 81.65  330      12.65858
# 36325 959            -4        US      ⋯ 28.04 10.04 46.26  260      13.80936
# 36326 959            -4        US      ⋯ 24.08  5.00 43.40  320      12.65858
# 36327 959            -4        US      ⋯ 26.96  5.00 38.50  260      14.96014
# 36328 959            -4        US      ⋯ 26.60 19.94 79.62   60      16.11092
# 36329 959            -4        US      ⋯ 30.92 26.96 85.05  300      14.96014
# 36330 959            -4        US      ⋯ 26.96  8.96 46.08  260      16.11092
# 36331 959            -4        US      ⋯ 24.98 19.40 79.62   80      10.35702
# 36332 959            -4        US      ⋯ 26.06 17.96 71.04  310       5.75390
# 36333 959            -4        US      ⋯ 33.08 19.94 58.08  220       8.05546
# 36334 959            -4        US      ⋯ 42.98 30.02 59.93  180       8.05546
# 36335 959            -4        US      ⋯ 51.98 44.96 76.88  230       8.05546
# 36336 959            -4        US      ⋯ 55.04 51.98 89.40  180      11.50780
# 36337 959            -4        US      ⋯ 57.92 55.04 90.11    0       0.00000
# 36338 959            -4        US      ⋯ 33.98 21.02 58.66  360      11.50780
# 36339 959            -4        US      ⋯ 19.94  6.08 54.30  330      10.35702
# 36340 959            -4        US      ⋯ 32.00 21.92 65.97   NA       4.60312
# 36341 959            -4        US      ⋯ 33.08 15.08 47.10  270      11.50780
# 36342 959            -4        US      ⋯ 37.04 21.02 51.95  210       9.20624
# 36343 959            -4        US      ⋯ 44.96 26.96 49.02  210       6.90468
# 36344 959            -4        US      ⋯ 44.06 35.06 70.42  240      11.50780
#       wind_gust precip pressure visib time_hour.y
# 1           NA  0.00   1011.9   10.00 2013-01-01 05:00:00
# 2           NA  0.00   1016.9   10.00 2013-01-02 05:00:00
# 3           NA  0.00   1022.0   10.00 2013-01-03 05:00:00
# 4           NA  0.00   1018.4   10.00 2013-01-04 05:00:00
# 5           NA  0.00   1021.0   10.00 2013-01-05 05:00:00
# 6           NA  0.00       NA    6.00 2013-01-06 05:00:00
# 7           NA  0.00   1021.7   10.00 2013-01-07 05:00:00
# 8           NA  0.00   1028.9   10.00 2013-01-08 05:00:00
# 9           NA  0.00   1028.0    9.00 2013-01-09 05:00:00
# 10    20.71404  0.00   1029.0   10.00 2013-01-10 05:00:00
# 11          NA  0.00   1031.7   10.00 2013-01-11 05:00:00
# 12          NA  0.00       NA    6.00 2013-01-12 05:00:00
# 13          NA  0.00       NA    0.25 2013-01-13 05:00:00
# 14          NA  0.00   1014.0    0.50 2013-01-14 05:00:00
# 15          NA  0.00   1025.2   10.00 2013-01-15 05:00:00
# 16          NA  0.09   1018.7    4.00 2013-01-16 05:00:00
# 17          NA  0.00   1014.5   10.00 2013-01-17 05:00:00
# 18          NA  0.00   1022.5   10.00 2013-01-18 05:00:00
# 19          NA  0.00   1026.5   10.00 2013-01-19 05:00:00
# 20          NA  0.00   1008.1   10.00 2013-01-20 05:00:00
# 21          NA  0.00   1018.8   10.00 2013-01-21 05:00:00
# 22    21.86482  0.00   1014.5   10.00 2013-01-22 05:00:00
# 23          NA  0.00   1023.8   10.00 2013-01-23 05:00:00
# 24          NA  0.00   1021.5   10.00 2013-01-24 05:00:00
# 25          NA  0.00   1030.0   10.00 2013-01-25 05:00:00
# 26          NA  0.00   1018.9   10.00 2013-01-26 05:00:00
# 27          NA  0.26   1031.1   10.00 2013-01-27 05:00:00
# 28          NA  0.00   1029.8   10.00 2013-01-28 05:00:00
# 29          NA  0.00   1018.4    7.00 2013-01-29 05:00:00
# 30          NA  0.00   1013.4    0.25 2013-01-30 05:00:00
# ⋮     ⋮         ⋮      ⋮        ⋮     ⋮
# 36315       NA  0.00   1023.8   10.00 2013-12-01 07:00:00
# 36316       NA  0.00   1015.1    9.00 2013-12-02 07:00:00
# 36317       NA  0.00   1013.2    7.00 2013-12-03 07:00:00
# 36318       NA  0.00   1019.3    7.00 2013-12-04 07:00:00
# 36319       NA  0.00   1019.0    0.25 2013-12-05 07:00:00
# 36320       NA  0.00       NA   10.00 2013-12-06 07:00:00
# 36321       NA  0.00   1024.6   10.00 2013-12-07 07:00:00
# 36322       NA  0.00   1035.6   10.00 2013-12-08 07:00:00
# 36323       NA  0.05       NA    3.00 2013-12-09 07:00:00
# 36324       NA  0.00   1015.6    2.50 2013-12-10 07:00:00
# 36325 25.31716  0.00   1026.4   10.00 2013-12-11 07:00:00
# 36326 21.86482  0.00   1027.3   10.00 2013-12-12 07:00:00
# 36327 25.31716  0.00   1022.0   10.00 2013-12-13 07:00:00
# 36328       NA  0.00       NA    8.00 2013-12-14 07:00:00
# 36329       NA  0.00   1000.7    8.00 2013-12-15 07:00:00
# 36330 20.71404  0.00   1016.8   10.00 2013-12-16 07:00:00
# 36331       NA  0.02       NA    1.50 2013-12-17 07:00:00
# 36332       NA  0.00   1016.5   10.00 2013-12-18 07:00:00
# 36333       NA  0.00   1020.5   10.00 2013-12-19 07:00:00
# 36334       NA  0.00   1019.1   10.00 2013-12-20 07:00:00
# 36335       NA  0.00   1015.1   10.00 2013-12-21 07:00:00
# 36336       NA  0.00   1010.9    7.00 2013-12-22 07:00:00
# 36337       NA  0.04   1015.0    5.00 2013-12-23 07:00:00
# 36338       NA  0.00   1020.9   10.00 2013-12-24 07:00:00
# 36339       NA  0.00   1032.7   10.00 2013-12-25 07:00:00
# 36340       NA  0.00       NA   10.00 2013-12-26 07:00:00
# 36341       NA  0.00   1027.6   10.00 2013-12-27 07:00:00
# 36342       NA  0.00   1023.3   10.00 2013-12-28 07:00:00
# 36343       NA  0.00   1016.3   10.00 2013-12-29 07:00:00
# 36344       NA  0.00   1011.9   10.00 2013-12-30 07:00:00

# %% [markdown]
# ### Defining the key columns
# When we do a join using `left_join()`, R take as the key whatever column names the two tables have in common:

# %%
left_join(flights, planes) %>% print
   # select(year, month, day, origin, type, tailnum, manufacturer) %>% 
   # print
# Out:
# Joining, by = c("year", "tailnum")
# # A tibble: 336,776 x 26
#     year month   day dep_time sched_dep_time dep_delay arr_time sched_arr_time
#    <int> <int> <int>    <int>          <int>     <dbl>    <int>          <int>
#  1  2013     1     1      517            515         2      830            819
#  2  2013     1     1      533            529         4      850            830
#  3  2013     1     1      542            540         2      923            850
#  4  2013     1     1      544            545        -1     1004           1022
#  5  2013     1     1      554            600        -6      812            837
#  6  2013     1     1      554            558        -4      740            728
#  7  2013     1     1      555            600        -5      913            854
#  8  2013     1     1      557            600        -3      709            723
#  9  2013     1     1      557            600        -3      838            846
# 10  2013     1     1      558            600        -2      753            745
# # … with 336,766 more rows, and 18 more variables: arr_delay <dbl>,
# #   carrier <chr>, flight <int>, tailnum <chr>, origin <chr>, dest <chr>,
# #   air_time <dbl>, distance <dbl>, hour <dbl>, minute <dbl>, time_hour <dttm>,
# #   type <chr>, manufacturer <chr>, model <chr>, engines <int>, seats <int>,
# #   speed <int>, engine <chr>

# %% [markdown]
# This is called a *natural join*. If the key column(s) are named differently in the two tables, we must specify the mapping between the two using the `by=` parameter.

# %% [markdown]
# Consider joining `airports` to `flights`:
# ```
# > left_join(flights, airports)
# Error: `by` required, because the data sources have no common variables
# Traceback:
#
# 1. left_join(flights, airports)
# 2. left_join.tbl_df(flights, airports)
# 3. common_by(by, x, y)
# 4. common_by.NULL(by, x, y)
# 5. bad_args("by", "required, because the data sources have no common variables")
# 6. glubort(fmt_args(args), ..., .envir = .envir)
# 7. .abort(text)
# ```

# %% [markdown]
# This has produced an error, because airports and flights do not have any columns in common. Indeed, the three digit FAA code is called `faa` in `airports`, but appears as either `origin` or `dest` in `flights`. To fix the error, we must specify which of `origin` or `dest` should be matched:

# %%
# join_by

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/World_map_indicating_tropics_and_subtropics.png/640px-World_map_indicating_tropics_and_subtropics.png" style="float: right; margin:0 0 0 20px;" />
#
# ## 🤔 Quiz
#
# How many flights in February were bound for tropical destinations?
#
# <ol style="list-style-type: upper-alpha;">
#     <li>56</li>
#     <li>18</li>
#     <li>71</li>
#     <li>39</li>
#     <li>50</li>
# </ol>
#
# (Note: there is a technical definition of what it means to be located in the tropics. It does not have to do with sitting on the beach.)

# %%
# tropical flights

airports %>% filter(lat <= 23.5)
# Out:
#    faa name                 lat      lon       alt  tz  dst tzone
# 1  BKH Barking Sands Pmrf   22.02283 -159.7850   23 -10 A   Pacific/Honolulu
# 2  BSF Bradshaw Aaf         19.76006 -155.5537 6190 -10 A   Pacific/Honolulu
# 3  HDH Dillingham           21.57947 -158.1973   14 -10 A   Pacific/Honolulu
# 4  HHI Wheeler Aaf          21.48350 -158.0397  837 -10 A   Pacific/Honolulu
# 5  HNL Honolulu Intl        21.31868 -157.9224   13 -10 N   Pacific/Honolulu
# 6  HNM Hana                 20.79564 -156.0144   78 -10 A   Pacific/Honolulu
# 7  ITO Hilo Intl            19.72137 -155.0485   38 -10 N   Pacific/Honolulu
# 8  JHM Kapalua              20.96294 -156.6730  256 -10 N   Pacific/Honolulu
# 9  KOA Kona Intl At Keahole 19.73877 -156.0456   47 -10 N   Pacific/Honolulu
# 10 LIH Lihue                21.97598 -159.3390  153 -10 N   Pacific/Honolulu
# 11 LNY Lanai                20.78561 -156.9514 1308 -10 N   Pacific/Honolulu
# 12 LUP Kalaupapa Airport    21.21100 -156.9740   24 -10 A   Pacific/Honolulu
# 13 MKK Molokai              21.15289 -157.0963  454 -10 N   Pacific/Honolulu
# 14 MUE Waimea Kohala        20.00133 -155.6681 2671 -10 A   Pacific/Honolulu
# 15 NGF Kaneohe Bay Mcaf     21.45045 -157.7680   24 -10 A   Pacific/Honolulu
# 16 OGG Kahului              20.89865 -156.4305   54 -10 N   Pacific/Honolulu
# 17 UPP Upolu                20.26526 -155.8600   96 -10 A   Pacific/Honolulu
# 18 WKL Waikoloa Heliport    19.91360 -155.8640  109 -10 N   Pacific/Honolulu

# %% [markdown]
# ## Filtering joins
#
# Filtering joins allow us to filter rows on one table based on their presence or absence in another table. We've already seen some examples of this on the problem sets:

# %%
dest_top6 <- count(flights, dest) %>% top_n(6)
filter(flights, dest %in% dest_top6$dest) %>% nrow
# Out:
# Selecting by n
# [1] 94326

# %% [markdown]
# ### Semi-join
# `semi_join(x, y)` keeps all the observations in `x` that are also in `y`.
# ![semi join](http://r4ds.had.co.nz/diagrams/join-semi.png)

# %%
# find all the flight with destinations in the top 6

# %% [markdown]
# ## 🤔 Quiz
# The top ten most popular days to fly were:
#
# ```count(flights, year, month, day) %>% top_n(10)```
#
# What is the overall fraction of flights that left on these ten days?
#
# <ol style="list-style-type: upper-alpha;">
#     <li>0.024</li>
#     <li>0.042</li>
#     <li>1.000</li>
#     <li>0.001</li>
#     <li>0.039</li>
# </ol>

# %% [markdown]
# ### Anti-join
# `anti_join(x, y)` _drops_ all the observations in `x` that are also in `y`.
# ![anti join](http://r4ds.had.co.nz/diagrams/join-anti.png)

# %% [markdown]
# ## Example
# All the tail numbers that are missing in planes:

# %%
# tail numbers in flights but not in planes

# %% [markdown]
# What do all these missing tail numbers have in common?

# %%
airports |>
  semi_join(flights, join_by(faa == dest)) |>
  ggplot(aes(x = lon, y = lat)) +
    borders("state") +
    geom_point() +
    coord_quickmap()
# Out:
# plot without title
