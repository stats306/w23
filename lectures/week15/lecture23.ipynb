# %%
options(repr.plot.width  = 8, plot.height = 5)
options(jupyter.plot_mimetypes = "image/png");
library(tidyverse)
library(lubridate)
library(modelr)

# %% [markdown]
# # Lecture 23
# ![image.png](attachment:image.png)

# %% [markdown]
# ## NCAA data
# Today we're going to study data from the latest season of NCAA basketball:

# %%
# ncaa_schools <- read_csv("ncaa_schools.csv")
# ncaa_2023 <- read_csv("ncaa_games_2023.csv") %>% mutate(game_date = lubridate::mdy(game_date)) %>% 
#     left_join(ncaa_schools)
# save(ncaa_2023, file="ncaa_2023.RData")
load(url('https://datasets.stats306.org/ncaa_2023.RData'))

# %%
ncaa_2023 %>% arrange(desc(game_date))
# Out:
#       opponent_name      game_date  score opponent_score location
# 1     UConn              2023-04-03  59    76            Neutral
# 2     San Diego St.      2023-04-03  76    59            Neutral
# 3     San Diego St.      2023-04-01  71    72            Neutral
# 4     UConn              2023-04-01  59    72            Neutral
# 5     Fla. Atlantic      2023-04-01  72    71            Neutral
# 6     Miami (FL)         2023-04-01  72    59            Neutral
# 7     UAB                2023-03-30  68    61            Neutral
# 8     North Texas        2023-03-30  61    68            Neutral
# 9     Wisconsin          2023-03-28  56    54            Neutral
# 10    Utah Valley        2023-03-28  88    86            Neutral
# 11    UAB                2023-03-28  86    88            Neutral
# 12    North Texas        2023-03-28  54    56            Neutral
# 13    San Diego St.      2023-03-26  56    57            Neutral
# 14    Texas              2023-03-26  88    81            Neutral
# 15    Creighton          2023-03-26  57    56            Neutral
# 16    Miami (FL)         2023-03-26  81    88            Neutral
# 17    Kansas St.         2023-03-25  79    76            Neutral
# 18    UConn              2023-03-25  54    82            Neutral
# 19    Fla. Atlantic      2023-03-25  76    79            Neutral
# 20    West Liberty       2023-03-25 111   101            Neutral
# 21    Gonzaga            2023-03-25  82    54            Neutral
# 22    Nova Southeastern  2023-03-25 101   111            Neutral
# 23    San Diego St.      2023-03-24  64    71            Neutral
# 24    Princeton          2023-03-24  86    75            Neutral
# 25    Miami (FL)         2023-03-24  75    89            Neutral
# 26    Houston            2023-03-24  89    75            Neutral
# 27    Creighton          2023-03-24  75    86            Neutral
# 28    Alabama            2023-03-24  71    64            Neutral
# 29    Xavier             2023-03-24  83    71            Neutral
# 30    Texas              2023-03-24  71    83            Neutral
# ⋮     ⋮                  ⋮          ⋮     ⋮              ⋮
# 31679 Penn St.           2022-11-07  68    93            Away
# 31680 Bradley            2022-11-07  59    93            Away
# 31681 South Dakota       2022-11-07  85    59            Home
# 31682 Bob Jones          2022-11-07 120    48            Home
# 31683 Colo. Christian    2022-11-07 102    69            Home
# 31684 Morgan St.         2022-11-07  96    73            Home
# 31685 Sarah Lawrence     2022-11-07  96    41            Home
# 31686 Canisius           2022-11-07  92    81            Away
# 31687 Lincoln Memorial   2022-11-06  83    81            Neutral
# 31688 Nova Southeastern  2022-11-06  65    95            Neutral
# 31689 West Tex. A&M      2022-11-06  92    90            Home
# 31690 Northwest Mo. St.  2022-11-06  75    88            Neutral
# 31691 Valdosta St.       2022-11-06  79    65            Neutral
# 31692 Alabama Huntsville 2022-11-06  81    83            Neutral
# 31693 Flagler            2022-11-06  88    75            Neutral
# 31694 DBU                2022-11-06  95    65            Neutral
# 31695 Hillsdale          2022-11-06  65    79            Neutral
# 31696 Fla. Southern      2022-11-06  90    92            Away
# 31697 Nova Southeastern  2022-11-05  81   101            Neutral
# 31698 Hillsdale          2022-11-05  57    64            Neutral
# 31699 Flagler            2022-11-05  96    80            Home
# 31700 Fla. Southern      2022-11-05  80    96            Away
# 31701 DBU                2022-11-05  64    57            Neutral
# 31702 Valdosta St.       2022-11-05 108    80            Neutral
# 31703 West Tex. A&M      2022-11-05  78    62            Neutral
# 31704 Alabama Huntsville 2022-11-05 101    81            Neutral
# 31705 Lincoln Memorial   2022-11-05  80   108            Neutral
# 31706 Northwest Mo. St.  2022-11-05  62    78            Neutral
# 31707 Midway             2022-10-28  87    65            Home
# 31708 Midway             2022-10-27  87    63            Home
#       neutral_site_location game_length attendence opponent_id year school_id
# 1     Houston, TX           NA          72423        164       2023   626
# 2     Houston, TX           NA          72423        626       2023   164
# 3     Houston, TX           NA          73860        626       2023   229
# 4     Houston, TX           NA          73860        164       2023   415
# 5     Houston, TX           NA          73860        229       2023   626
# 6     Houston, TX           NA          73860        415       2023   164
# 7     Las Vegas, NV         NA           1290          9       2023   497
# 8     Las Vegas, NV         NA           1290        497       2023     9
# 9     Las Vegas, NV         NA           2931        796       2023   497
# 10    Las Vegas, NV         1 OT         2931      30024       2023     9
# 11    Las Vegas, NV         1 OT         2931          9       2023 30024
# 12    Las Vegas, NV         NA           2931        497       2023   796
# 13    Louisville, KY        NA          20051        626       2023   169
# 14    Kansas City, MO       NA          17530        703       2023   415
# 15    Louisville, KY        NA          20051        169       2023   626
# 16    Kansas City, MO       NA          17530        415       2023   703
# 17    New York, NY          NA          19680        327       2023   229
# 18    Las Vegas, NV         NA          18119        164       2023   260
# 19    New York, NY          NA          19680        229       2023   327
# 20    Evansville, IN        NA           1231       1438       2023 24639
# 21    Las Vegas, NV         NA          18119        260       2023   164
# 22    Evansville, IN        NA           1231      24639       2023  1438
# 23    Louisville, KY        NA          20289        626       2023     8
# 24    Louisville, KY        NA          20289        554       2023   169
# 25    Kansas City, MO       NA          17429        415       2023   288
# 26    Kansas City, MO       NA          17429        288       2023   415
# 27    Louisville, KY        NA          20289        169       2023   554
# 28    Louisville, KY        NA          20289          8       2023   626
# 29    Kansas City, MO       NA          17429        812       2023   703
# 30    Kansas City, MO       NA          17429        703       2023   812
# ⋮     ⋮                     ⋮           ⋮          ⋮           ⋮    ⋮
# 31679 NA                    NA           6572        539       2023   792
# 31680 NA                    NA           3761         72       2023   799
# 31681 NA                    NA          14349        650       2023   796
# 31682 NA                    NA           1680      30232       2023  2915
# 31683 NA                    NA           4464      11403       2023   811
# 31684 NA                    NA          10224        446       2023   812
# 31685 NA                    NA            695      30163       2023   813
# 31686 NA                    NA           1391        116       2023   817
# 31687 Lakeland, FL          NA            123       1176       2023    10
# 31688 Lakeland, FL          NA            131      24639       2023  1045
# 31689 NA                    NA            357        767       2023   233
# 31690 Lakeland, FL          NA            123        507       2023 30092
# 31691 Lakeland, FL          NA            123        734       2023   280
# 31692 Lakeland, FL          NA            123         10       2023  1176
# 31693 Lakeland, FL          NA            123      30092       2023   507
# 31694 Lakeland, FL          NA            131       1045       2023 24639
# 31695 Lakeland, FL          NA            123        280       2023   734
# 31696 NA                    NA            357        233       2023   767
# 31697 Lakeland, FL          NA            123      24639       2023    10
# 31698 Lakeland, FL          NA            123        280       2023  1045
# 31699 NA                    NA            431      30092       2023   233
# 31700 NA                    NA            431        233       2023 30092
# 31701 Lakeland, FL          NA            123       1045       2023   280
# 31702 Lakeland, FL          NA            231        734       2023  1176
# 31703 Lakeland, FL          NA            257        767       2023   507
# 31704 Lakeland, FL          NA            123         10       2023 24639
# 31705 Lakeland, FL          NA            231       1176       2023   734
# 31706 Lakeland, FL          NA            257        507       2023   767
# 31707 NA                    NA            810         NA       2023    11
# 31708 NA                    NA            899         NA       2023    11
#       school_name
# 1     San Diego St.
# 2     UConn
# 3     Fla. Atlantic
# 4     Miami (FL)
# 5     San Diego St.
# 6     UConn
# 7     North Texas
# 8     UAB
# 9     North Texas
# 10    UAB
# 11    Utah Valley
# 12    Wisconsin
# 13    Creighton
# 14    Miami (FL)
# 15    San Diego St.
# 16    Texas
# 17    Fla. Atlantic
# 18    Gonzaga
# 19    Kansas St.
# 20    Nova Southeastern
# 21    UConn
# 22    West Liberty
# 23    Alabama
# 24    Creighton
# 25    Houston
# 26    Miami (FL)
# 27    Princeton
# 28    San Diego St.
# 29    Texas
# 30    Xavier
# ⋮     ⋮
# 31679 Winthrop
# 31680 Wis.-Parkside
# 31681 Wisconsin
# 31682 Wofford
# 31683 Wyoming
# 31684 Xavier
# 31685 Yale
# 31686 Youngstown St.
# 31687 Alabama Huntsville
# 31688 DBU
# 31689 Fla. Southern
# 31690 Flagler
# 31691 Hillsdale
# 31692 Lincoln Memorial
# 31693 Northwest Mo. St.
# 31694 Nova Southeastern
# 31695 Valdosta St.
# 31696 West Tex. A&M
# 31697 Alabama Huntsville
# 31698 DBU
# 31699 Fla. Southern
# 31700 Flagler
# 31701 Hillsdale
# 31702 Lincoln Memorial
# 31703 Northwest Mo. St.
# 31704 Nova Southeastern
# 31705 Valdosta St.
# 31706 West Tex. A&M
# 31707 Alas. Anchorage
# 31708 Alas. Anchorage

# %% [markdown]
# ## Logistic regression model
# To predict the results of March Madness, we need a way to estimate
#
# $$\mathbb{P}(\text{Team A will beat team B on a neutral court}).$$
#
# There are many different possible strategies. In this lecture, we will focus on a model that depends on only one thing: the *margin of victory* when they played in the regular season. We will estimate
#
# $$\mathbb{P}(\text{Team A will beat team B on a neutral court}\mid \text{Team A's home margin vs. Team B was $x$ points}).$$
#
#
# That is, we want to estimate a function $p(x)$ that returns this probability.

# %% [markdown]
# Recall logistic regression from last week:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 🤔 Quiz
#
# Suppose Michigan has a $p=.8$ chance of winning the NCAA title. What are Michigan's *log-odds* of winning?
#
# (Hint: their odds of winning are $p/(1-p) = 4:1$.
#
# <ol style="list-style-type: upper-alpha;">
#     <li>-1.38</li>
#     <li>-.25</li>
#     <li>0.0</li>
#     <li>.25</li>
#     <li>1.38</li>
# </ol>

# %%
# log odds

# %% [markdown]
# ## 🤔 Quiz
#
# Suppose the log-odds of Michigan winning the NCAA title are 1.0. What is Michigan's *probability* of winning?
#
# Hint:
#
# $$
# \begin{align}
# x &= \log\left(\frac{p}{1-p}\right) \\
# p &= \frac{1}{1+\exp(-x)}
# \end{align}
# $$
#
# <ol style="list-style-type: upper-alpha;">
#     <li>-.51</li>
#     <li>0.0</li>
#     <li>.12</li>
#     <li>.73</li>
#     <li>.99</li>
# </ol>

# %%
# probability of winning

# %% [markdown]
# ## 🤔 Quiz
#
# ```
# Call:  glm(formula = y ~ x, family = "binomial")
#
# Coefficients:
# (Intercept)            x
#     -0.7879       0.8797
#
# Degrees of Freedom: 2200 Total (i.e. Null);  2199 Residual
# Null Deviance:	    2769
# Residual Deviance: 2750 	AIC: 2754
# ```
#
# When $x=1.3$, what is the predicted probability that $y=1$?
#
# <ol style="list-style-type: upper-alpha;">
#     <li>50-60%</li>
#     <li>60-70%</li>
#     <li>70-80%</li>
#     <li>80-90%</li>
#     <li>&gt; 90%</li>
# </ol>

# %%
# predicted probability

# %% [markdown]
# $$\mathbb{P}(\text{Team A will beat team B on a neutral court}\mid \text{Team A's home margin vs. Team B was $x$ points}).$$
#
# Can we use logistic regression to estimate this model? No, because we do not observe the left hand side! So first, we have to think of a way around that.

# %% [markdown]
# ### Home-court advantage
#
# - If a team is playing at home, let's assume that they get an automatic boost of $+h$ points, known as the _home-court advantage_.
# - A team that wins by $x$ points at home would be expected to win by $x – h$ at the neutral site.
# - How do we estimate the home court advantage? Thinking back to our model, consider the value of $h$ such that
#
# $$\mathbb{P}(\text{Team A will beat team B on an away court}\mid \text{Team A's home margin vs. Team B was $h$ points}) = \frac{1}{2}.$$
#
# - This says that A's inherent advantage over B is exactly cancelled out by B's home court advantage.
# - Thus, A's advantage in front of their home crowd is $2h$, and their advantage in front of a neutral crowd is $h$.

# %% [markdown]
# So
# $$\mathbb{P}(\text{Team A will beat team B on a neutral court}\mid \text{Team A's home margin vs. Team B was $x$ points}) \approx \mathbb{P}(\text{Team A will beat team B on B's court}\mid \text{Team A's home margin vs. Team B was $x + h$ points}).$$

# %% [markdown]
# To use logistic regression to estimate this function, we'll create a dataset of pairs of games. Most conference teams play each other twice per season, once at each campus. We'll look at the outcome of one of the games and use it to predict the outcome of the second game according to the above model.

# %% [markdown]
# ### Data format
# To estimate this regression model, we need a data frame that looks like:
# ```
# # A tibble: 8,958 × 2
#    beat_on_road home_margin
#    <lgl>              <dbl>
#  1 FALSE                 22
#  2 FALSE                  7
#  3 FALSE                 -6
#  4 TRUE                  30
#  5 FALSE                 -9
#  6 TRUE                  -3
#  7 TRUE                  18
#  8 FALSE                  2
#  9 FALSE                 12
# 10 TRUE                  10
# # … with 8,948 more rows
# ```

# %% [markdown]
# I had to think for a few minutes about how to create this data frame. We'll to it in stages:

# %%
# 1. keep only the rows and columns we're interested in
gp1 <- ncaa_2023 %>% filter(location != "Neutral") %>% 
    select(location, school_name, opponent_name, score, opponent_score, game_date) %>%
    print
# Out:
# # A tibble: 28,631 × 6
#    location school_name        opponent_name   score opponent_score game_date
#    <chr>    <chr>              <chr>           <dbl>          <dbl> <date>
#  1 Away     A&M-Corpus Christi Mississippi St.    44             63 2022-11-07
#  2 Home     A&M-Corpus Christi UTSA               75             55 2022-11-11
#  3 Home     A&M-Corpus Christi Trinity (TX)       91             73 2022-11-14
#  4 Home     A&M-Corpus Christi UTRGV              97             75 2022-11-17
#  5 Away     A&M-Corpus Christi UTEP               67             72 2022-11-25
#  6 Away     A&M-Corpus Christi UTRGV              82             89 2022-11-30
#  7 Home     A&M-Corpus Christi Texas Lutheran    100             63 2022-12-07
#  8 Away     A&M-Corpus Christi Arizona            61             99 2022-12-13
#  9 Home     A&M-Corpus Christi Schreiner         104             69 2022-12-16
# 10 Away     A&M-Corpus Christi Oklahoma St.       58             81 2022-12-20
# # … with 28,621 more rows

# %%
# 2. place home and away team into an easier format
gp2 <- gp1 %>% mutate(
        home_team = ifelse(location == "Home", school_name, opponent_name),
        away_team = ifelse(location == "Away", school_name, opponent_name),
        home_score = ifelse(location == "Home", score, opponent_score),
        away_score = ifelse(location == "Away", score, opponent_score)
    ) %>% select(starts_with(c("home", "away")), game_date) %>% print
# Out:
# # A tibble: 28,631 × 5
#    home_team          home_score away_team          away_score game_date
#    <chr>                   <dbl> <chr>                   <dbl> <date>
#  1 Mississippi St.            63 A&M-Corpus Christi         44 2022-11-07
#  2 A&M-Corpus Christi         75 UTSA                       55 2022-11-11
#  3 A&M-Corpus Christi         91 Trinity (TX)               73 2022-11-14
#  4 A&M-Corpus Christi         97 UTRGV                      75 2022-11-17
#  5 UTEP                       72 A&M-Corpus Christi         67 2022-11-25
#  6 UTRGV                      89 A&M-Corpus Christi         82 2022-11-30
#  7 A&M-Corpus Christi        100 Texas Lutheran             63 2022-12-07
#  8 Arizona                    99 A&M-Corpus Christi         61 2022-12-13
#  9 A&M-Corpus Christi        104 Schreiner                  69 2022-12-16
# 10 Oklahoma St.               81 A&M-Corpus Christi         58 2022-12-20
# # … with 28,621 more rows

# %%
# 3. get the two games that each team played side-by-side
gp3 <- inner_join(gp2, gp2, 
                  join_by(home_team == away_team, away_team == home_team), 
                  suffix=c("_1", "_2")) %>%
        filter(game_date_1 != game_date_2) %>% distinct %>% print
# Out:
# Warning message in inner_join(gp2, gp2, join_by(home_team == away_team, away_team == :
# “Each row in `x` is expected to match at most 1 row in `y`.
# ℹ Row 4 of `x` matches multiple rows.
# ℹ If multiple matches are expected, set `multiple = "all"` to silence this warning.”
# # A tibble: 8,958 × 8
#    home_team       home_…¹ away_…² away_…³ game_dat…⁴ home_…⁵ away_…⁶ game_dat…⁷
#    <chr>             <dbl> <chr>     <dbl> <date>       <dbl>   <dbl> <date>
#  1 A&M-Corpus Chr…      97 UTRGV        75 2022-11-17      89      82 2022-11-30
#  2 UTRGV                89 A&M-Co…      82 2022-11-30      97      75 2022-11-17
#  3 Northwestern S…      59 A&M-Co…      65 2022-12-31      83      75 2023-02-25
#  4 A&M-Corpus Chr…      91 UIW          61 2023-01-04      71      80 2023-01-07
#  5 UIW                  71 A&M-Co…      80 2023-01-07      91      61 2023-01-04
#  6 A&M-Corpus Chr…      82 Southe…      85 2023-01-12      72      83 2023-02-04
#  7 A&M-Corpus Chr…      97 New Or…      79 2023-01-14      69      86 2023-02-02
#  8 Lamar Universi…      68 A&M-Co…      66 2023-01-19      61      52 2023-02-11
#  9 Houston Christ…      90 A&M-Co…      78 2023-01-21      91      68 2023-02-09
# 10 A&M-Corpus Chr…      96 Nichol…      86 2023-01-26      74      78 2023-02-16
# # … with 8,948 more rows, and abbreviated variable names ¹​home_score_1,
# #   ²​away_team, ³​away_score_1, ⁴​game_date_1, ⁵​home_score_2, ⁶​away_score_2,
# #   ⁷​game_date_2

# %%
# 4. create columns for regression
game_pairs <- gp3 %>% 
    mutate(home_margin = home_score_1 - away_score_1, beat_on_road = away_score_2 > home_score_2)
select(game_pairs, beat_on_road, home_margin)
# Out:
#      beat_on_road home_margin
# 1    FALSE         22
# 2    FALSE          7
# 3    FALSE         -6
# 4     TRUE         30
# 5    FALSE         -9
# 6     TRUE         -3
# 7     TRUE         18
# 8    FALSE          2
# 9    FALSE         12
# 10    TRUE         10
# 11    TRUE         11
# 12    TRUE         11
# 13   FALSE        -17
# 14    TRUE        -11
# 15   FALSE         23
# 16   FALSE          9
# 17   FALSE         -4
# 18   FALSE        -23
# 19    TRUE         -4
# 20    TRUE          8
# 21    TRUE         -5
# 22   FALSE        -17
# 23    TRUE          7
# 24   FALSE          6
# 25   FALSE          9
# 26    TRUE         30
# 27   FALSE         -2
# 28   FALSE        -15
# 29    TRUE         10
# 30   FALSE         -4
# ⋮    ⋮            ⋮
# 8929  TRUE         23
# 8930  TRUE         40
# 8931  TRUE          3
# 8932  TRUE         -4
# 8933 FALSE         -9
# 8934  TRUE         23
# 8935  TRUE         19
# 8936  TRUE         36
# 8937 FALSE        -11
# 8938  TRUE         19
# 8939 FALSE         -4
# 8940  TRUE         -4
# 8941 FALSE        -20
# 8942  TRUE        -13
# 8943  TRUE         -4
# 8944  TRUE         16
# 8945 FALSE        -20
# 8946  TRUE         -3
# 8947 FALSE        -27
# 8948  TRUE         20
# 8949 FALSE         24
# 8950 FALSE         -3
# 8951 FALSE         14
# 8952  TRUE         20
# 8953  TRUE         27
# 8954 FALSE         -6
# 8955 FALSE         -3
# 8956  TRUE          8
# 8957 FALSE        -11
# 8958  TRUE          2

# %%
ggplot(game_pairs, aes(x = beat_on_road, y = home_margin)) + geom_boxplot()

# %%
model = glm(beat_on_road ~ home_margin, data = game_pairs, family = "binomial")
summary(model)
# Out:
# Call:
# glm(formula = beat_on_road ~ home_margin, family = "binomial",
#     data = game_pairs)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.9818  -1.0118  -0.6783   1.1471   2.3611
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept) -0.455685   0.023621  -19.29   <2e-16 ***
# home_margin  0.052750   0.001771   29.78   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 12240  on 8957  degrees of freedom
# Residual deviance: 11174  on 8956  degrees of freedom
# AIC: 11178
#
# Number of Fisher Scoring iterations: 4

# %% [markdown]
# Let's see how well our logistic regression model fits to data:

# %%
predictions <- game_pairs %>% group_by(home_margin) %>% 
    summarize(p_win = mean(beat_on_road), sdp = sd(beat_on_road)) %>%
    add_predictions(model) %>% mutate(pred = plogis(pred))

# %%
predictions %>% 
    ggplot(aes(x = home_margin)) + 
    geom_col(aes(y = p_win)) + 
    geom_line(aes(y = pred), color = "red")

# %% [markdown]
# Our logistic regression model is
#
# $$\log \left( \frac{p}{1-p} \right) = \alpha + \beta x.$$
#
# If $p=1/2$ then the LHS is zero, and we get simply $h = -\alpha/\beta$.

# %%
beta = coef(model)
h = -beta[1] / beta[2]
h
r_H = function(x) plogis(beta[1] + beta[2] * (x + h))
r_H(0)
# Out:
# (Intercept)
#    8.638662
# (Intercept)
#         0.5

# %% [markdown]
# ## Ranking the teams: logistic regression MCMC
# We will use a model called [logistic regression MCMC](https://pdfs.semanticscholar.org/bb21/8ea8e16cc43afb7f50eefc0bea4b0fd35ff1.pdf) to build rankings for the NCAA teams. The basic model is as follows:
# - We imagine that there is an imaginary person whose job it is to vote on the best team.
# - The voter picks a random team as the best to begin with, and then iterates the following procedure:
#     - Given that the voter currently believes that team $A$ is the best, she picks a random game that team $A$ played versus some team $B$.
#     - With probability $p$, the voter decides that the winner of $A$ vs. $B$ is the new best team, and with probability $(1-p)$ the voter decides that the *loser* is the new best team.

# %% [markdown]
# Suppose team $i$ played $N_i$ games in total. Let $w_{ij}$ and $\ell_{ij}$ be the number of games that $i$ won/lost against team $j$. The probability that our voter goes from thinking that $i$ is the best team, to thinking that $j$ is the best team, is
#
# $$M_{ij} =\frac{1}{N_i}[w_{ij}(1-p) + \ell_{ij}(p)].$$

# %% [markdown]
# The probability $p$ should not necessarily be fixed. It should be high if team $A$ was "clearly better" than team $B$, whereas if $A$ just "barely beat" team $B$ then it should be close to 1/2. We will use $p$ estimates that we obtained from the model above to fit this model.

# %% [markdown]
# Finally we construct our voter model. We'll make a matrix whose entry $M_{ij}$ equals the probability, estimated by our logistic regression model, that team $i$ is better than team $j$. Each time we cast a vote with probability $M_{ij}$ that team $i$ is better than team $j$. Our estimate of the best team is the one for whom we most frequently vote.

# %% [markdown]
# Let's illustrate this procedure with three teams: <span style="color: navy;">Michigan</span>, <span style="color: darkgreen">Michigan State</span>, and <span style="color: red;">Ohio State</span>. Our matrix M looks like:
#
# $$
# M =
# \begin{pmatrix}
# \color{navy}{.6} & \color{darkgreen}{.3} & \color{red}{.1}  \\
# \color{navy}{.2} & \color{darkgreen}{.4} & \color{red}{.4}  \\
# \color{navy}{.7} & \color{darkgreen}{.1} & \color{red}{.2}
# \end{pmatrix}
# $$

# %% [markdown]
# Row/column 1 corresponds to Michigan, row/column 2 to MSU, row/column 3 corresponds to Ohio State. If I'm in row 1, then there is a 30% chance that I vote for Michigan State to be the best, and a 10% chance that I vote for Ohio State to be the best; otherwise, I vote for Michigan to be the best.

# %%
mioh <- c("UM", "MSU", "OSU")
M = matrix(c(.6, .2, .7, .3, .4, .1, .1, .4, .2), nrow=3, dimnames=list(mioh, mioh)) %>% print
# Out:
#      UM MSU OSU
# UM  0.6 0.3 0.1
# MSU 0.2 0.4 0.4
# OSU 0.7 0.1 0.2

# %% [markdown]
# We can simulate one round of voting by multiplying this matrix with itself:

# %%
M %*% M
# ^^^ matrix multiplication
# Out:
#     UM   MSU  OSU
# UM  0.49 0.31 0.20
# MSU 0.48 0.26 0.26
# OSU 0.58 0.27 0.15

# %% [markdown]
# If we repeat this a large number of times, something interesting happens:

# %%
P <- M
for (i in 1:10) P <- P %*% P
P
# Out:
#     UM        MSU       OSU
# UM  0.5057471 0.2873563 0.2068966
# MSU 0.5057471 0.2873563 0.2068966
# OSU 0.5057471 0.2873563 0.2068966

# %% [markdown]
# The probabilities have converged.

# %% [markdown]
# Technically this is a Markov chain. The vector of stationary probabilities is exactly the eigenvector of the matrix $M$ corresponding to eigenvalue 1. You can learn more about Markov chains in STATS 430.

# %%
evd <- eigen(t(M))
p <- evd$vectors[,1]
p <- abs(p / sum(p))
names(p) <- rownames(M)
p
# Out:
#        UM       MSU       OSU
# 0.5057471 0.2873563 0.2068966

# %% [markdown]
# The cool thing about this approach is that it works even when every team did not play every other team.
#
# $$
# M =
# \begin{pmatrix}
# \color{navy}{.6} & \color{darkgreen}{.4} & \color{red}{0}  \\
# \color{navy}{.2} & \color{darkgreen}{.4} & \color{red}{.4}  \\
# \color{navy}{0} & \color{darkgreen}{.5} & \color{red}{.5}
# \end{pmatrix}
# $$

# %%
M = matrix(c(.6, .2, 0, .4, .4, .5, 0, .4, .5), nrow=3, dimnames=list(mioh, mioh)) %>% print
evd <- eigen(t(M))
p <- evd$vectors[,1]
(p <- abs(p / sum(p)) %>% setNames(rownames(M)))
# Out:
#      UM MSU OSU
# UM  0.6 0.4 0.0
# MSU 0.2 0.4 0.4
# OSU 0.0 0.5 0.5
#        UM       MSU       OSU
# 0.2173913 0.4347826 0.3478261

# %% [markdown]
# Now let's write code that forms this matrix for all the teams in our data set. To make things go faster, we're only going to look at the teams that formed the midwest portion of this year's tournament bracked

# %%
filter(gp.pred, home_team == "Texas A&M") %>% 
    mutate(win = (home_score_1 > away_score_1) + (home_score_2 < away_score_2),
           loss = 2 - win) %>% select(home_team, away_team, win, loss, p=pred)
# Out:
#   home_team away_team win loss p
# 1 Texas A&M Arkansas  1   1    0.4652590
# 2 Texas A&M Auburn    2   0    0.4521623
# 3 Texas A&M Florida   2   0    0.4133372
# 4 Texas A&M LSU       2   0    0.5572623
# 5 Texas A&M Missouri  2   0    0.6210027

# %%
all_teams <- game_pairs$home_team %>% sort %>% unique
M <- matrix(0, nrow=length(all_teams), ncol=length(all_teams))
rownames(M) <- all_teams
colnames(M) <- all_teams
gp.pred <- mutate(game_pairs, p=r_H(home_margin))
for (team in all_teams) {
    df <- filter(gp.pred, home_team == team) %>% 
        mutate(win = (home_score_1 > away_score_1) + (home_score_2 < away_score_2),
               loss = 2 - win)
    v <- df$win * p + df$loss * (1 - p)
    M[team, df$away_team] = v / sum(v)
}

# %% [markdown]
# Now we have a large matrix $M$ that implements the "voter model" described a few slides ago: the probability that the voter goes from thinking team $i$ is the best to the thinking team $j$ is the best is given by $M_{ij}$. Let's check these probabilities in a few cases:

# %%
P <- M
for (i in 1:20) P <- P %*% P
-sort(P[1,])
# Out:
#    A&M-Corpus Christi     Abilene Christian        Academy of Art
#                     0                     0                     0
#             Adams St.               Adelphi                Adrian
#                     0                     0                     0
#             Air Force                 Akron               Alabama
#                     0                     0                     0
#           Alabama A&M    Alabama Huntsville           Alabama St.
#                     0                     0                     0
#       Alas. Anchorage       Alas. Fairbanks       Albany St. (GA)
#                     0                     0                     0
#       Albertus Magnus                Albion              Albright
#                     0                     0                     0
#                Alcorn     Alderson Broaddus                Alfred
#                     0                     0                     0
#            Alfred St.           Alice Lloyd             Allegheny
#                     0                     0                     0
#                 Allen              Alliance                  Alma
#                     0                     0                     0
#              Alvernia              American        American Int'l
#                     0                     0                     0
#               Amherst         Anderson (IN)         Anderson (SC)
#                     0                     0                     0
#            Angelo St.            Anna Maria             App State
#                     0                     0                     0
#               Arcadia               Arizona           Arizona St.
#                     0                     0                     0
#       Ark.-Fort Smith       Ark.-Monticello       Ark.-Pine Bluff
#                     0                     0                     0
#              Arkansas          Arkansas St.         Arkansas Tech
#                     0                     0                     0
#       Army West Point                Asbury               Ashland
#                     0                     0                     0
#            Assumption                Auburn              Augsburg
#                     0                     0                     0
#               Augusta        Augustana (IL)        Augustana (SD)
#                     0                     0                     0
#                   AUM                Aurora                Austin
#                     0                     0                     0
#           Austin Peay               Averett         Azusa Pacific
#                     0                     0                     0
#                Babson       Baldwin Wallace              Ball St.
#                     0                     0                     0
#                  Bard                 Barry                Barton
#                     0                     0                     0
#                Baruch                 Bates                Baylor
#                     0                     0                     0
#              Belhaven            Bellarmine               Belmont
#                     0                     0                     0
#         Belmont Abbey                Beloit           Bemidji St.
#                     0                     0                     0
#              Benedict      Benedictine (IL)               Bentley
#                     0                     0                     0
#                 Berea                 Berry          Bethany (WV)
#                     0                     0                     0
#      Bethany Lutheran           Bethel (MN)       Bethune-Cookman
#                     0                     0                     0
#            Binghamton                 Biola        Birmingham-So.
#                     0                     0                     0
#       Black Hills St.             Blackburn            Bloomfield
#                     0                     0                     0
#            Bloomsburg         Bluefield St.              Bluffton
#                     0                     0                     0
#             Bob Jones             Boise St.        Boston College
#                     0                     0                     0
#             Boston U.               Bowdoin             Bowie St.
#                     0                     0                     0
#         Bowling Green                 Boyce               Bradley
#                     0                     0                     0
#              Brandeis               Brevard            Bridgeport
#                     0                     0                     0
#      Bridgewater (VA)       Bridgewater St.              Brooklyn
#                     0                     0                     0
#                 Brown                Bryant            Bryn Athyn
#                     0                     0                     0
#              Bucknell           Buena Vista               Buffalo
#                     0                     0                     0
#           Buffalo St.                Butler                   BYU
#                     0                     0                     0
#               Cabrini                 Cairn          Cal Lutheran
#                     0                     0                     0
#              Cal Poly     Cal Poly Humboldt       Cal Poly Pomona
#                     0                     0                     0
#    Cal St. Dom. Hills      Cal St. East Bay     Cal St. Fullerton
#                     0                     0                     0
#  Cal St. Monterey Bay    Cal St. San B'dino    Cal St. San Marcos
#                     0                     0                     0
#          Cal State LA              Caldwell            California
#                     0                     0                     0
#       California (PA)    California Baptist               Caltech
#                     0                     0                     0
#                Calvin               Cameron     Camp. Harrodsburg
#                     0                     0                     0
#              Campbell              Canisius               Capital
#                     0                     0                     0
#              Carleton       Carnegie Mellon          Carroll (WI)
#                     0                     0                     0
#         Carson-Newman              Carthage             Castleton
#                     0                     0                     0
#               Catawba              Catholic             Cazenovia
#                     0                     0                     0
#                  CCNY            Cedarville        Centenary (LA)
#                     0                     0                     0
#        Centenary (NJ)          Central (IA)          Central Ark.
#                     0                     0                     0
#     Central Conn. St.         Central Mich.           Central Mo.
#                     0                     0                     0
#         Central Okla.      Central St. (OH)         Central Wash.
#                     0                     0                     0
#                Centre           Chadron St.             Chaminade
#                     0                     0                     0
#               Chapman       Charleston (WV)        Charleston So.
#                     0                     0                     0
#             Charlotte               Chatham           Chattanooga
#                     0                     0                     0
#         Chestnut Hill           Chicago St.             Chico St.
#                     0                     0                     0
#                Chowan        Chris. Newport    Christian Brothers
#                     0                     0                     0
#            Cincinnati               Claflin         Claremont-M-S
#                     0                     0                     0
#               Clarion            Clark (MA)         Clark Atlanta
#                     0                     0                     0
#         Clarks Summit              Clarkson           Clayton St.
#                     0                     0                     0
#               Clemson         Cleveland St.                  CMSV
#                     0                     0                     0
#           Coast Guard      Coastal Carolina        Cobleskill St.
#                     0                     0                     0
#                   Coe                 Coker    Col. of Charleston
#                     0                     0                     0
#                 Colby          Colby-Sawyer               Colgate
#                     0                     0                     0
#       Colo. Christian   Colo. Sch. of Mines              Colorado
#                     0                     0                     0
#         Colorado Col.         Colorado Mesa          Colorado St.
#                     0                     0                     0
#              Columbia          Columbus St.               Concord
#                     0                     0                     0
#        Concordia (TX)   Concordia Wisconsin      Concordia-M'head
#                     0                     0                     0
#    Concordia-St. Paul              Converse            Coppin St.
#                     0                     0                     0
#               Cornell       Cornell College              Cortland
#                     0                     0                     0
#              Covenant             Creighton            Crown (MN)
#                     0                     0                     0
#       CSU Bakersfield            CSU Pueblo                  CSUN
#                     0                     0                     0
#                   CUI                 Curry                  CWRU
#                     0                     0                     0
#            D'Youville                Daemen                Dallas
#                     0                     0                     0
#             Dartmouth             Davenport              Davidson
#                     0                     0                     0
#        Davis & Elkins                Dayton                   DBU
#                     0                     0                     0
#                  Dean              Defiance              Delaware
#                     0                     0                     0
#          Delaware St.       Delaware Valley             Delta St.
#                     0                     0                     0
#               Denison                Denver                DePaul
#                     0                     0                     0
#                DePauw               DeSales         Detroit Mercy
#                     0                     0                     0
#             Dickinson        Dist. Columbia        Dominican (CA)
#                     0                     0                     0
#        Dominican (IL)        Dominican (NY)                 Drake
#                     0                     0                     0
#                  Drew                Drexel                 Drury
#                     0                     0                     0
#               Dubuque                  Duke              Duquesne
#                     0                     0                     0
#               Earlham         East Carolina          East Central
#                     0                     0                     0
#      East Stroudsburg     East Tex. Baptist       East. Mennonite
#                     0                     0                     0
#               Eastern     Eastern Conn. St.          Eastern Ill.
#                     0                     0                     0
#           Eastern Ky.         Eastern Mich.          Eastern N.M.
#                     0                     0                     0
#      Eastern Nazarene         Eastern Wash.                Eckerd
#                     0                     0                     0
#              Edgewood              Edinboro         Edward Waters
#                     0                     0                     0
#    Elizabeth City St.         Elizabethtown              Elmhurst
#                     0                     0                     0
#                Elmira                  Elms                  Elon
#                     0                     0                     0
#     Embry-Riddle (FL)               Emerson         Emmanuel (GA)
#                     0                     0                     0
#         Emmanuel (MA)                Emmaus                 Emory
#                     0                     0                     0
#         Emory & Henry           Emporia St.              Endicott
#                     0                     0                     0
#               Erskine                  ETSU                Eureka
#                     0                     0                     0
#            Evansville             Fairfield          Fairmont St.
#                     0                     0                     0
#     Faith Bapt. Bible       Farmingdale St.      Fayetteville St.
#                     0                     0                     0
#                   FDU           FDU-Florham              Felician
#                     0                     0                     0
#            Ferris St.                Ferrum                  FGCU
#                     0                     0                     0
#               Findlay             Finlandia         Fitchburg St.
#                     0                     0                     0
#                   FIU         Fla. Atlantic         Fla. Southern
#                     0                     0                     0
#               Flagler               Florida           Florida A&M
#                     0                     0                     0
#           Florida St.          Florida Tech             Fontbonne
#                     0                     0                     0
#               Fordham         Fort Hays St.            Fort Lewis
#                     0                     0                     0
#       Fort Valley St.        Framingham St.        Francis Marion
#                     0                     0                     0
#            Franciscan              Franklin   Franklin & Marshall
#                     0                     0                     0
#       Franklin Pierce              Fredonia        Fresno Pacific
#                     0                     0                     0
#            Fresno St.         Frostburg St.                Furman
#                     0                     0                     0
#          Ga. Southern      Ga. Southwestern             Gallaudet
#                     0                     0                     0
#                Gannon          Gardner-Webb                Geneva
#                     0                     0                     0
#            George Fox          George Mason     George Washington
#                     0                     0                     0
#            Georgetown               Georgia       Georgia College
#                     0                     0                     0
#           Georgia St.          Georgia Tech        Georgian Court
#                     0                     0                     0
#            Gettysburg         Glenville St.         Goldey-Beacom
#                     0                     0                     0
#               Gonzaga                Gordon               Goucher
#                     0                     0                     0
#             Grambling          Grand Canyon      Grand Valley St.
#                     0                     0                     0
#             Green Bay            Greensboro            Greenville
#                     0                     0                     0
#              Grinnell            Grove City              Guilford
#                     0                     0                     0
#        Gust. Adolphus         Gwynedd Mercy               Hamline
#                     0                     0                     0
#        Hampden-Sydney               Hampton               Hanover
#                     0                     0                     0
#        Hardin-Simmons               Harding              Hartford
#                     0                     0                     0
#              Hartwick               Harvard             Haverford
#                     0                     0                     0
#                Hawaii           Hawaii Hilo        Hawaii Pacific
#                     0                     0                     0
#            Heidelberg         Henderson St.               Hendrix
#                     0                     0                     0
#            High Point               Hilbert             Hillsdale
#                     0                     0                     0
#                 Hiram                Hobart               Hofstra
#                     0                     0                     0
#            Holy Cross           Holy Family            Holy Names
#                     0                     0                     0
#                  Hood                  Hope              Houghton
#                     0                     0                     0
#               Houston     Houston Christian                Howard
#                     0                     0                     0
#          Howard Payne                Hunter            Huntingdon
#                     0                     0                     0
#                Husson                 Idaho             Idaho St.
#                     0                     0                     0
#                   IIT      Ill. Springfield         Ill. Wesleyan
#                     0                     0                     0
#              Illinois         Illinois Col.          Illinois St.
#                     0                     0                     0
#            Immaculata               Indiana          Indiana (PA)
#                     0                     0                     0
#           Indiana St.                  Iona                  Iowa
#                     0                     0                     0
#              Iowa St.                Ithaca                 IUPUI
#                     0                     0                     0
#           Jackson St.          Jacksonville      Jacksonville St.
#                     0                     0                     0
#         James Madison             Jefferson          John Carroll
#                     0                     0                     0
#              John Jay         Johns Hopkins          Johnson (FL)
#                     0                     0                     0
#      Johnson C. Smith               Juniata       JWU (Charlotte)
#                     0                     0                     0
#      JWU (Providence)             Kalamazoo                Kansas
#                     0                     0                     0
#           Kansas City            Kansas St.                  Kean
#                     0                     0                     0
#             Keene St.          Kennesaw St.              Kent St.
#                     0                     0                     0
#              Kentucky          Kentucky St.                Kenyon
#                     0                     0                     0
#                 Keuka              Keystone             King (TN)
#                     0                     0                     0
#           King's (PA)                  Knox              Kutztown
#                     0                     0                     0
#          Ky. Wesleyan              La Roche              La Salle
#                     0                     0                     0
#              La Verne             Lafayette              LaGrange
#                     0                     0                     0
#             Lake Erie           Lake Forest     Lake Superior St.
#                     0                     0                     0
#              Lakeland      Lamar University       Lancaster Bible
#                     0                     0                     0
#                Lander                  Lane                Lasell
#                     0                     0                     0
#              Lawrence              Le Moyne        Lebanon Valley
#                     0                     0                     0
#                   Lee            Lees-McRae                Lehigh
#                     0                     0                     0
#                Lehman          LeMoyne-Owen          Lenoir-Rhyne
#                     0                     0                     0
#                Lesley            LeTourneau                 Lewis
#                     0                     0                     0
#         Lewis & Clark               Liberty             Limestone
#                     0                     0                     0
#          Lincoln (MO)          Lincoln (PA)      Lincoln Memorial
#                     0                     0                     0
#            Lindenwood              Linfield              Lipscomb
#                     0                     0                     0
#           Little Rock                   LIU           Livingstone
#                     0                     0                     0
#              LMU (CA)            Lock Haven        Long Beach St.
#                     0                     0                     0
#              Longwood                 Loras             Louisiana
#                     0                     0                     0
#        Louisiana Tech            Louisville        Loyola Chicago
#                     0                     0                     0
#       Loyola Maryland                   LSU     Lubbock Christian
#                     0                     0                     0
#                Luther              Lycoming             Lynchburg
#                     0                     0                     0
#                  Lynn            Macalester                 Maine
#                     0                     0                     0
#        Maine Maritime                Malone            Manchester
#                     0                     0                     0
#             Manhattan        Manhattanville             Mansfield
#                     0                     0                     0
#     Maranatha Baptist           Marian (WI)              Marietta
#                     0                     0                     0
#                Marist             Marquette             Mars Hill
#                     0                     0                     0
#              Marshall         Martin Luther                  Mary
#                     0                     0                     0
#          Mary Baldwin    Mary Hardin-Baylor       Mary Washington
#                     0                     0                     0
#              Maryland        Marymount (VA)        Maryville (MO)
#                     0                     0                     0
#        Maryville (TN)              Marywood         Massachusetts
#                     0                     0                     0
#              McDaniel             McKendree                  MCLA
#                     0                     0                     0
#               McMurry               McNeese           Me.-Augusta
#                     0                     0                     0
#        Me.-Farmington         Me.-Fort Kent      Me.-Presque Isle
#                     0                     0                     0
#              Medaille          Medgar Evers               Memphis
#                     0                     0                     0
#                Mercer       Merchant Marine                 Mercy
#                     0                     0                     0
#            Mercyhurst             Merrimack               Messiah
#                     0                     0                     0
#             Methodist            Miami (FL)            Miami (OH)
#                     0                     0                     0
#              Michigan          Michigan St.         Michigan Tech
#                     0                     0                     0
#          Middle Tenn.                Midway        Midwestern St.
#                     0                     0                     0
#                 Miles          Millersville              Millikin
#                     0                     0                     0
#              Millsaps             Milwaukee          Minn. Duluth
#                     0                     0                     0
#       Minn.-Crookston          Minn.-Morris             Minnesota
#                     0                     0                     0
#         Minnesota St.             Minot St.          Misericordia
#                     0                     0                     0
#      Mississippi Col.       Mississippi St.      Mississippi Val.
#                     0                     0                     0
#              Missouri          Missouri S&T          Missouri St.
#                     0                     0                     0
#      Missouri Western                   MIT              Mitchell
#                     0                     0                     0
#      Mo. Southern St.         Mo.-St. Louis                Molloy
#                     0                     0                     0
#              Monmouth         Monmouth (IL)    Mont. St. Billings
#                     0                     0                     0
#               Montana           Montana St.         Montclair St.
#                     0                     0                     0
#            Montevallo           Moody Bible              Moravian
#                     0                     0                     0
#          Morehead St.             Morehouse            Morgan St.
#                     0                     0                     0
#                Morris        Mount Aloysius           Mount Olive
#                     0                     0                     0
#      Mount St. Mary's           Mount Union                  MSOE
#                     0                     0                     0
#            MSU Denver          MSU Moorhead        Mt. St. Joseph
#                     0                     0                     0
#     Mt. St. Mary (NY)            Muhlenberg             Multnomah
#                     0                     0                     0
#            Murray St.             Muskingum                   MUW
#                     0                     0                     0
#              N.C. A&T          N.C. Central         N.C. Wesleyan
#                     0                     0                     0
#        N.M. Highlands                  Navy              Nazareth
#                     0                     0                     0
#              NC State         Neb. Wesleyan          Neb.-Kearney
#                     0                     0                     0
#              Nebraska               Neumann                Nevada
#                     0                     0                     0
#      New England Col.         New Hampshire             New Haven
#                     0                     0                     0
#       New Jersey City            New Mexico        New Mexico St.
#                     0                     0                     0
#           New Orleans              Newberry                Newman
#                     0                     0                     0
#               Niagara              Nicholls               Nichols
#                     0                     0                     0
#                   NIU                  NJIT           Norfolk St.
#                     0                     0                     0
#            North Ala.        North Carolina    North Central (IL)
#                     0                     0                     0
#    North Central (MN)          North Dakota      North Dakota St.
#                     0                     0                     0
#         North Florida         North Georgia      North Greenville
#                     0                     0                     0
#            North Park           North Texas          Northeastern
#                     0                     0                     0
#      Northeastern St.        Northern Ariz.        Northern Colo.
#                     0                     0                     0
#          Northern Ky.        Northern Mich.          Northern St.
#                     0                     0                     0
#             Northland     Northwest Mo. St.    Northwest Nazarene
#                     0                     0                     0
#          Northwestern    Northwestern Okla.      Northwestern St.
#                     0                     0                     0
# Northwestern-St. Paul             Northwood               Norwich
#                     0                     0                     0
#            Notre Dame       Notre Dame (OH)     Nova Southeastern
#                     0                     0                     0
#           NVU-Johnson            NVU-Lyndon                   NYU
#                     0                     0                     0
#   Oak Hills Christian               Oakland               Oberlin
#                     0                     0                     0
#            Occidental            Oglethorpe                  Ohio
#                     0                     0                     0
#        Ohio Dominican         Ohio Northern              Ohio St.
#                     0                     0                     0
#         Ohio Wesleyan         Okla. Baptist       Okla. Christian
#                     0                     0                     0
#              Oklahoma          Oklahoma St.          Old Dominion
#                     0                     0                     0
#          Old Westbury              Ole Miss                Olivet
#                     0                     0                     0
#                 Omaha          Oral Roberts                Oregon
#                     0                     0                     0
#            Oregon St.            Oswego St.             Otterbein
#                     0                     0                     0
#      Ouachita Baptist           Ozarks (AR)                  Pace
#                     0                     0                     0
#               Pacific          Pacific (OR)      Pacific Lutheran
#                     0                     0                     0
#                 Paine       Palm Beach Atl.                  Penn
#                     0                     0                     0
#          Penn College              Penn St.   Penn St. Harrisburg
#                     0                     0                     0
#     Penn St.-Abington      Penn St.-Altoona      Penn St.-Behrend
#                     0                     0                     0
#        Penn St.-Berks   Pensacola Christian            Pepperdine
#                     0                     0                     0
#              Pfeiffer              Piedmont        Pitt.-Bradford
#                     0                     0                     0
#      Pitt.-Greensburg       Pitt.-Johnstown         Pittsburg St.
#                     0                     0                     0
#            Pittsburgh       Plattsburgh St.          Plymouth St.
#                     0                     0                     0
#            Point Loma         Pomona-Pitzer              Portland
#                     0                     0                     0
#        Portland Bible          Portland St.                  Post
#                     0                     0                     0
#          Prairie View          Presbyterian          Presentation
#                     0                     0                     0
#             Princeton             Principia            Providence
#                     0                     0                     0
#           Puget Sound              Purchase                Purdue
#                     0                     0                     0
#     Purdue Fort Wayne      Purdue Northwest           Queens (NC)
#                     0                     0                     0
#           Queens (NY)                Quincy            Quinnipiac
#                     0                     0                     0
#               Radford                Ramapo              Randolph
#                     0                     0                     0
#        Randolph-Macon              Redlands            Regis (CO)
#                     0                     0                     0
#            Regis (MA)            Rensselaer          Rhode Island
#                     0                     0                     0
#     Rhode Island Col.                Rhodes                  Rice
#                     0                     0                     0
#              Richmond                 Rider                 Ripon
#                     0                     0                     0
#                   RIT                Rivier               Roanoke
#                     0                     0                     0
#         Robert Morris      Roberts Wesleyan        Rochester (NY)
#                     0                     0                     0
#              Rockford             Rockhurst        Rocky Mountain
#                     0                     0                     0
#        Roger Williams            Rogers St.               Rollins
#                     0                     0                     0
#           Rose-Hulman              Rosemont                 Rowan
#                     0                     0                     0
#          Russell Sage               Rutgers        Rutgers-Camden
#                     0                     0                     0
#        Rutgers-Newark        Sacramento St.          Sacred Heart
#                     0                     0                     0
#        Saginaw Valley     Saint Augustine's       Saint Elizabeth
#                     0                     0                     0
#    Saint Francis (PA)     Saint John's (MN)     Saint Joseph (CT)
#                     0                     0                     0
#        Saint Joseph's             Saint Leo           Saint Louis
#                     0                     0                     0
#        Saint Martin's     Saint Mary's (CA)     Saint Mary's (MN)
#                     0                     0                     0
#       Saint Michael's         Saint Peter's            Saint Rose
#                     0                     0                     0
#         Saint Vincent            Salem (WV)             Salem St.
#                     0                     0                     0
#             Salisbury          Salve Regina           Sam Houston
#                     0                     0                     0
#               Samford             San Diego         San Diego St.
#                     0                     0                     0
#         San Fran. St.         San Francisco          San Jose St.
#                     0                     0                     0
#           Santa Clara        Sarah Lawrence          Savannah St.
#                     0                     0                     0
#             Schreiner              Scranton       Seattle Pacific
#                     0                     0                     0
#             Seattle U            Seton Hall            Seton Hill
#                     0                     0                     0
#               Sewanee                   SFA                  Shaw
#                     0                     0                     0
#            Shenandoah              Shepherd          Shippensburg
#                     0                     0                     0
#               Shorter                 Siena          Simmons (KY)
#                     0                     0                     0
#          Simon Fraser               Simpson           Sioux Falls
#                     0                     0                     0
#                  SIUE              Skidmore         Slippery Rock
#                     0                     0                     0
#                   SMU            Sonoma St.         South Alabama
#                     0                     0                     0
#        South Carolina    South Carolina St.          South Dakota
#                     0                     0                     0
#    South Dakota Mines      South Dakota St.            South Fla.
#                     0                     0                     0
#     Southeast Mo. St.    Southeastern Bapt.      Southeastern La.
#                     0                     0                     0
#    Southeastern Okla.         Southern Ark.   Southern California
#                     0                     0                     0
#    Southern Conn. St.         Southern Ill.         Southern Ind.
#                     0                     0                     0
#          Southern Me.        Southern Miss.         Southern N.H.
#                     0                     0                     0
#     Southern Nazarene           Southern U.         Southern Utah
#                     0                     0                     0
#          Southern Va.     Southern Wesleyan     Southwest Baptist
#                     0                     0                     0
#   Southwest Minn. St.     Southwestern (TX)    Southwestern Okla.
#                     0                     0                     0
#              Spalding           Spring Hill           Springfield
#                     0                     0                     0
#            St. Anselm       St. Bonaventure         St. Cloud St.
#                     0                     0                     0
#          St. Edward's  St. Francis Brooklyn       St. John Fisher
#                     0                     0                     0
#       St. John's (NY)  St. Joseph's (Brkln)   St. Joseph's (L.I.)
#                     0                     0                     0
#     St. Joseph's (ME)          St. Lawrence       St. Mary's (MD)
#                     0                     0                     0
#       St. Mary's (TX)           St. Norbert              St. Olaf
#                     0                     0                     0
#       St. Scholastica       St. Thomas (MN)       St. Thomas (TX)
#                     0                     0                     0
#    St. Thomas Aquinas              Stanford        Stanislaus St.
#                     0                     0                     0
#         Staten Island               Stetson               Stevens
#                     0                     0                     0
#             Stevenson              Stockton             Stonehill
#                     0                     0                     0
#           Stony Brook               Suffolk          Sul Ross St.
#                     0                     0                     0
#        SUNY Brockport           SUNY Canton            SUNY Delhi
#                     0                     0                     0
#          SUNY Geneseo         SUNY Maritime      SUNY Morrisville
#                     0                     0                     0
#        SUNY New Paltz          SUNY Oneonta             SUNY Poly
#                     0                     0                     0
#          SUNY Potsdam           Susquehanna            Swarthmore
#                     0                     0                     0
#              Syracuse                 Tampa          Tarleton St.
#                     0                     0                     0
#                  TCNJ                   TCU                Temple
#                     0                     0                     0
#             Tennessee         Tennessee St.        Tennessee Tech
#                     0                     0                     0
#        Tex. A&M Int'l     Tex. A&M-Commerce   Tex. A&M-Kingsville
#                     0                     0                     0
#    Tex. Permian Basin                 Texas             Texas A&M
#                     0                     0                     0
#        Texas Lutheran        Texas Southern             Texas St.
#                     0                     0                     0
#            Texas Tech          Texas-Dallas           The Citadel
#                     0                     0                     0
#                 Thiel           Thomas (ME)                Tiffin
#                     0                     0                     0
#          Toccoa Falls                Toledo                Towson
#                     0                     0                     0
#          Transylvania     Trevecca Nazarene                 Trine
#                     0                     0                     0
#          Trinity (CT)          Trinity (TX)       Trinity Baptist
#                     0                     0                     0
#                  Troy            Truman St.                Tulane
#                     0                     0                     0
#                 Tulsa              Tusculum              Tuskegee
#                     0                     0                     0
#         U New England                   UAB               UAlbany
#                     0                     0                     0
#           UC Clermont              UC Davis             UC Irvine
#                     0                     0                     0
#          UC Riverside          UC San Diego      UC Santa Barbara
#                     0                     0                     0
#         UC Santa Cruz      UC-Colo. Springs                   UCF
#                     0                     0                     0
#              UChicago                  UCLA                 UConn
#                     0                     0                     0
#                   UIC                 UIndy                   UIW
#                     0                     0                     0
#                   ULM          UMass Boston       UMass Dartmouth
#                     0                     0                     0
#          UMass Lowell                  UMBC                  UMES
#                     0                     0                     0
#         UNC Asheville        UNC Greensboro          UNC Pembroke
#                     0                     0                     0
#                  UNCW                   UNI            Union (NY)
#                     0                     0                     0
#            Union (TN)                  UNLV            Upper Iowa
#                     0                     0                     0
#               Ursinus             USC Aiken           USC Upstate
#                     0                     0                     0
#          UT Arlington             UT Martin              UT Tyler
#                     0                     0                     0
#                  Utah              Utah St.             Utah Tech
#                     0                     0                     0
#           Utah Valley                  UTEP                 Utica
#                     0                     0                     0
#                 UTRGV                  UTSA              UVA Wise
#                     0                     0                     0
#        UW-River Falls          Va. Wesleyan          Valdosta St.
#                     0                     0                     0
#          Valley Forge            Valparaiso            Vanderbilt
#                     0                     0                     0
#                Vassar                   VCU               Vermont
#                     0                     0                     0
#             Villanova              Virginia          Virginia St.
#                     0                     0                     0
#         Virginia Tech        Virginia Union    Virginia-Lynchburg
#                     0                     0                     0
#                   VMI                Wabash                Wagner
#                     0                     0                     0
#           Wake Forest                 Walsh         Warren Wilson
#                     0                     0                     0
#              Wartburg         Wash. & Jeff.           Wash. & Lee
#                     0                     0                     0
#              Washburn            Washington  Washington Adventist
#                     0                     0                     0
#       Washington Col.        Washington St.                 WashU
#                     0                     0                     0
#        Wayne St. (MI)        Wayne St. (NE)            Waynesburg
#                     0                     0                     0
#             Weber St.               Webster                 Wells
#                     0                     0                     0
#             Wentworth         Wesleyan (CT)             West Ala.
#                     0                     0                     0
#          West Chester          West Florida              West Ga.
#                     0                     0                     0
#          West Liberty         West Tex. A&M     West Va. Wesleyan
#                     0                     0                     0
#         West Virginia     West Virginia St.              WestConn
#                     0                     0                     0
#         Western Caro.         Western Colo.          Western Ill.
#                     0                     0                     0
#           Western Ky.         Western Mich.          Western N.M.
#                     0                     0                     0
#      Western New Eng.          Western Ore.         Western Wash.
#                     0                     0                     0
#         Westfield St.      Westminster (MO)      Westminster (PA)
#                     0                     0                     0
#      Westminster (UT)          Wheaton (IL)          Wheaton (MA)
#                     0                     0                     0
#              Wheeling               Whitman              Whittier
#                     0                     0                     0
#             Whitworth           Wichita St.               Widener
#                     0                     0                     0
#                Wilkes            Willamette        William & Mary
#                     0                     0                     0
#        William Jewell         William Peace              Williams
#                     0                     0                     0
#       Wilmington (DE)       Wilmington (OH)                Wilson
#                     0                     0                     0
#               Wingate            Winona St.         Winston-Salem
#                     0                     0                     0
#              Winthrop         Wis. Lutheran       Wis.-Eau Claire
#                     0                     0                     0
#        Wis.-La Crosse          Wis.-Oshkosh         Wis.-Parkside
#                     0                     0                     0
#      Wis.-Platteville    Wis.-Stevens Point            Wis.-Stout
#                     0                     0                     0
#         Wis.-Superior       Wis.-Whitewater             Wisconsin
#                     0                     0                     0
#            Wittenberg          Wm. Paterson               Wofford
#                     0                     0                     0
#               Wooster         Worcester St.                   WPI
#                     0                     0                     0
#            Wright St.               Wyoming                Xavier
#                     0                     0                     0
#                  Yale               Yeshiva             York (NY)
#                     0                     0                     0
#             York (PA)          Young Harris        Youngstown St.
#                     0                     0                     0

# %% [markdown]
# Suppose we let the voter vote for an infinite number of rounds, and then take the average amount of time that she believes each school is "the best". For each school $i$, we get a number $p_i \in [0,1]$ that measures the fraction of time that the voter thought that school $i$ was "the best". The $p_i$ are like rankings for each school; larger is better.

# %%
rankings <- tibble(school_name = names(p), p = p)
rankings %>% arrange(desc(p)) %>% print
# Out:
# # A tibble: 1,124 x 2
#    school_name          p
#    <chr>            <dbl>
#  1 Kansas         0.00494
#  2 Duke           0.00482
#  3 North Carolina 0.00433
#  4 Louisville     0.00425
#  5 Kentucky       0.00417
#  6 Wisconsin      0.00415
#  7 Florida        0.00401
#  8 Arizona        0.00390
#  9 Ohio St.       0.00389
# 10 Pittsburgh     0.00385
# # ... with 1,114 more rows
